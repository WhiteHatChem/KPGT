# %%
import json
import os
import sys

from settings import settings

# %%
datasets={
    'bace',
 'bbbp',
 'clintox',
# 'esol',
# 'freesolv',
# 'lipo',
 'metstab',
 'sider',
 'tox21',
 'toxcast'
 }

# %%
descriptions={
    "bace": {
        "links":[],
        "description": "A dataset focused on predicting the inhibitory effects of molecules on the enzyme beta-secretase 1 (BACE1). BACE1 inhibition is a potential target for Alzheimer's disease treatment.",
     "tasks":{
        "Class": "Predicts whether a given molecule will inhibit the enzyme beta-secretase 1 (BACE1), which is important in Alzheimer's disease pathology."
      }  
      },
    "bbbp": {
        "links":[],
        "description": "A dataset providing insights on the ability of molecules to penetrate the blood-brain barrier. Crucial for understanding the potential of molecules as central nervous system drugs.",
            "tasks":{
        "p_np": "Predicts the blood-brain barrier permeability of molecules. Molecules that can cross this barrier might have potential as central nervous system drugs."
            }
    },
    "clintox": {
        "links":[],
        "description": "This dataset deals with the FDA approval status and clinical trial toxicity of molecules. Important for understanding the safety and regulatory status of compounds.",
          "tasks":{
        "FDA_APPROVED": "Predicts if a molecule is approved by the FDA.",
        "CT_TOX": "Predicts if a molecule has been determined to be toxic in clinical trials."
          }
    },
    "esol": {
        "links":[],
        "description": "A dataset that predicts the solubility of molecules in water. Solubility is an essential property influencing bioavailability and the potential formulation of a drug.",
           "tasks":{
        "logSolubility": "Predicts the solubility of molecules in water, given in logarithmic scale (log(mol/L))."
           }
    },
    "freesolv": {
        "links":[],
        "description": "This dataset is centered on predicting the free energy when a molecule is dissolved in water. The energy changes can affect molecular interactions in biological systems.",
           "tasks":{
        "freesolv": "Predicts the free energy of solvation in water, given in kcal/mol."
           }
    },
    "lipo": {
        "links":[],
        "description": "A dataset predicting the lipophilicity of molecules. Lipophilicity is a crucial factor affecting the distribution, metabolism, and excretion of drugs in the body.",
           "tasks":{
        "lipo": "Predicts the lipophilicity of molecules, represented by AlogP."
           }
    },
    "metstab": {
        "links":[],
        "description": "This dataset gives insights into the metabolic stability of molecules. High metabolic stability often results in a longer half-life, influencing drug dosage and frequency.",
            "tasks":{
        "high": "Predicts high metabolic stability of a molecule.",
        "low": "Predicts low metabolic stability of a molecule."
            }
    }
,
    "sider": {
      "links":[],
   "description": "A dataset highlighting the potential side effects of molecules. Each field represents a category of adverse effects. This dataset aids in understanding the safety profile and potential side effects associated with molecules.",
     "tasks":{
        "Hepatobiliary disorders": "Predicts if a molecule is associated with disorders of the liver, gallbladder, or bile ducts.",
        "Metabolism and nutrition disorders": "Predicts if a molecule is related to metabolic or nutritional disturbances.",
        "Product issues": "Predicts if there are any issues with the molecule as a product.",
        "Eye disorders": "Predicts if a molecule is linked with eye-related disorders.",
        "Investigations": "Predicts if a molecule requires further investigations.",
        "Musculoskeletal and connective tissue disorders": "Predicts if a molecule affects the muscles, bones, or connective tissues.",
        "Gastrointestinal disorders": "Predicts if a molecule is associated with disorders of the digestive system.",
        "Social circumstances": "Predicts if a molecule has effects influenced by social factors.",
        "Immune system disorders": "Predicts if a molecule impacts the immune system.",
        "Reproductive system and breast disorders": "Predicts if a molecule affects reproductive organs or breasts.",
        "Neoplasms benign, malignant and unspecified (incl cysts and polyps)": "Predicts if a molecule is associated with tumors, whether benign, malignant or unspecified.",
        "General disorders and administration site conditions": "Predicts general disorders or issues at the administration site caused by a molecule.",
        "Endocrine disorders": "Predicts if a molecule is associated with hormone-related disorders.",
        "Surgical and medical procedures": "Predicts if a molecule is related to complications in surgical or medical procedures.",
        "Vascular disorders": "Predicts if a molecule affects the vascular system.",
        "Blood and lymphatic system disorders": "Predicts if a molecule is related to disorders of the blood or lymphatic system.",
        "Skin and subcutaneous tissue disorders": "Predicts if a molecule causes disorders of the skin or underlying tissue.",
        "Congenital, familial and genetic disorders": "Predicts if a molecule is linked to hereditary or birth-related disorders.",
        "Infections and infestations": "Predicts if a molecule is associated with increased risk of infections or infestations.",
        "Respiratory, thoracic and mediastinal disorders": "Predicts if a molecule impacts the respiratory system or surrounding regions.",
        "Psychiatric disorders": "Predicts if a molecule causes or exacerbates mental health disorders.",
        "Renal and urinary disorders": "Predicts if a molecule affects the kidneys or urinary system.",
        "Pregnancy, puerperium and perinatal conditions": "Predicts if a molecule is associated with conditions related to pregnancy or the period immediately after childbirth.",
        "Ear and labyrinth disorders": "Predicts if a molecule is linked to disorders of the ear or inner ear.",
        "Cardiac disorders": "Predicts if a molecule affects the heart.",
        "Nervous system disorders": "Predicts if a molecule impacts the nervous system.",
        "Injury, poisoning and procedural complications": "Predicts if a molecule is related to injuries, poisonings, or complications from procedures."
     }
  
    },
    "tox21": {
        "links":[],
        "description": "This dataset revolves around predicting the toxicity of molecules against various nuclear receptors and stress response pathways. The different outputs such as 'NR-AR', 'NR-AhR', etc., represent different biological targets and pathways, and the goal is to predict how molecules will interact with or affect them.",
             "tasks":{
        "NR-AR": "Androgen Receptor.",
        "NR-AR-LBD": "Androgen Receptor Ligand Binding Domain.",
        "NR-AhR": "Aryl Hydrocarbon Receptor.",
        "NR-Aromatase": "Aromatase enzyme.",
        "NR-ER": "Estrogen Receptor.",
        "NR-ER-LBD": "Estrogen Receptor Ligand Binding Domain.",
        "NR-PPAR-gamma": "Peroxisome Proliferator-Activated Receptor Gamma.",
        "SR-ARE": "Antioxidant Response Element.",
        "SR-ATAD5": "ATAD5 protein, related to DNA damage response.",
        "SR-HSE": "Heat Shock Element.",
        "SR-MMP": "Mitochondrial Membrane Potential.",
        "SR-p53": "p53 pathway related to cell cycle and apoptosis."
    },
    },
    "toxcast": {
       "links":["https://www.toxicology.org/groups/rc/nlsot/docs/Dix.pdf"],
        "description": "This dataset offers predictions related to the potential toxicological effects of molecules on various cellular and genetic targets. Each entry represents a distinct biological or cellular response.",
      "tasks":{
        "ACEA_T47D_80hr_Negative": "Prediction of negative response in the ACEA T47D 80-hour assay.",
        "ACEA_T47D_80hr_Positive": "Prediction of positive response in the ACEA T47D 80-hour assay.",
        "APR_HepG2_CellCycleArrest_24h_dn": "Predicts a down-regulation of cell cycle arrest in HepG2 cells at the 24-hour mark.",
        "APR_HepG2_CellCycleArrest_24h_up": "Predicts an up-regulation of cell cycle arrest in HepG2 cells at the 24-hour mark.",
        "APR_HepG2_CellCycleArrest_72h_dn": "Predicts a down-regulation of cell cycle arrest in HepG2 cells at the 72-hour mark.",
        "APR_HepG2_CellLoss_24h_dn": "Predicts a decrease in HepG2 cell count at the 24-hour mark.",
        "APR_HepG2_CellLoss_72h_dn": "Predicts a decrease in HepG2 cell count at the 72-hour mark.",


"APR_HepG2_MitoMass_24h_dn": "Predicts a decrease in mitochondrial mass in HepG2 cells at the 24-hour mark.",
        "APR_HepG2_MitoMass_24h_up": "Predicts an increase in mitochondrial mass in HepG2 cells at the 24-hour mark.",
        "APR_HepG2_MitoMass_72h_dn": "Predicts a decrease in mitochondrial mass in HepG2 cells at the 72-hour mark.",
        "APR_HepG2_MitoMass_72h_up": "Predicts an increase in mitochondrial mass in HepG2 cells at the 72-hour mark.",
        "APR_HepG2_MitoMembPot_1h_dn": "Predicts a decrease in mitochondrial membrane potential in HepG2 cells after 1 hour.",
        "APR_HepG2_MitoMembPot_24h_dn": "Predicts a decrease in mitochondrial membrane potential in HepG2 cells at the 24-hour mark.",
        "APR_HepG2_MitoMembPot_72h_dn": "Predicts a decrease in mitochondrial membrane potential in HepG2 cells at the 72-hour mark.",
        "ATG_AP_1_CIS_dn": "Predicts a down-regulation related to the AP-1 cis-regulatory element.",
        "ATG_AP_1_CIS_up": "Predicts an up-regulation related to the AP-1 cis-regulatory element.",
        "ATG_AP_2_CIS_dn": "Predicts a down-regulation related to the AP-2 cis-regulatory element.",
        "ATG_AR_TRANS_dn": "Predicts a down-regulation in the androgen receptor (AR) transcriptional activity.",
        "ATG_AR_TRANS_up": "Predicts an up-regulation in the androgen receptor (AR) transcriptional activity.",
        "ATG_Ahr_CIS_dn": "Predicts a down-regulation related to the Aryl hydrocarbon receptor (AhR) cis-regulatory element.",
        "ATG_Ahr_CIS_up": "Predicts an up-regulation related to the Aryl hydrocarbon receptor (AhR) cis-regulatory element.",
"ATG_BRE_CIS_dn": "Predicts a down-regulation related to the BRE cis-regulatory element.",
        "ATG_BRE_CIS_up": "Predicts an up-regulation related to the BRE cis-regulatory element.",
        "ATG_CAR_TRANS_dn": "Predicts a down-regulation in the Constitutive Androstane Receptor (CAR) transcriptional activity.",
        "ATG_CAR_TRANS_up": "Predicts an up-regulation in the Constitutive Androstane Receptor (CAR) transcriptional activity.",
        "ATG_CMV_CIS_dn": "Predicts a down-regulation related to the CMV cis-regulatory element.",
        "ATG_CMV_CIS_up": "Predicts an up-regulation related to the CMV cis-regulatory element.",
        "ATG_CRE_CIS_dn": "Predicts a down-regulation related to the CRE (cAMP Response Element) cis-regulatory element.",
        "ATG_CRE_CIS_up": "Predicts an up-regulation related to the CRE (cAMP Response Element) cis-regulatory element.",
        "ATG_C_EBP_CIS_dn": "Predicts a down-regulation related to the C/EBP (CCAAT/Enhancer Binding Protein) cis-regulatory element.",
        "ATG_C_EBP_CIS_up": "Predicts an up-regulation related to the C/EBP (CCAAT/Enhancer Binding Protein) cis-regulatory element.",
        "ATG_DR4_LXR_CIS_dn": "Predicts a down-regulation related to the DR4-LXR cis-regulatory element.",
        "ATG_DR4_LXR_CIS_up": "Predicts an up-regulation related to the DR4-LXR cis-regulatory element.",
        "ATG_DR5_CIS_dn": "Predicts a down-regulation related to the DR5 cis-regulatory element.",
        "ATG_DR5_CIS_up": "Predicts an up-regulation related to the DR5 cis-regulatory element.",
        "ATG_E2F_CIS_dn": "Predicts a down-regulation related to the E2F cis-regulatory element.",
        "ATG_E2F_CIS_up": "Predicts an up-regulation related to the E2F cis-regulatory element.",
         "ATG_EGR_CIS_up": "Predicts an up-regulation related to the EGR (Early Growth Response) cis-regulatory element.",
        "ATG_ERE_CIS_dn": "Predicts a down-regulation related to the ERE (Estrogen Response Element) cis-regulatory element.",
        "ATG_ERE_CIS_up": "Predicts an up-regulation related to the ERE (Estrogen Response Element) cis-regulatory element.",
        "ATG_ERRa_TRANS_dn": "Predicts a down-regulation in the ERRa (Estrogen Related Receptor Alpha) transcriptional activity.",
        "ATG_ERRg_TRANS_dn": "Predicts a down-regulation in the ERRg (Estrogen Related Receptor Gamma) transcriptional activity.",
        "ATG_ERRg_TRANS_up": "Predicts an up-regulation in the ERRg (Estrogen Related Receptor Gamma) transcriptional activity.",
        "ATG_ERa_TRANS_up": "Predicts an up-regulation in the ERa (Estrogen Receptor Alpha) transcriptional activity.",
        "ATG_E_Box_CIS_dn": "Predicts a down-regulation related to the E-Box cis-regulatory element.",
        "ATG_E_Box_CIS_up": "Predicts an up-regulation related to the E-Box cis-regulatory element.",
        "ATG_Ets_CIS_dn": "Predicts a down-regulation related to the Ets (E26 transformation-specific) cis-regulatory element.",
        "ATG_Ets_CIS_up": "Predicts an up-regulation related to the Ets (E26 transformation-specific) cis-regulatory element.",
        "ATG_FXR_TRANS_up": "Predicts an up-regulation in the FXR (Farnesoid X Receptor) transcriptional activity.",
        "ATG_FoxA2_CIS_dn": "Predicts a down-regulation related to the FoxA2 cis-regulatory element.",
        "ATG_FoxA2_CIS_up": "Predicts an up-regulation related to the FoxA2 cis-regulatory element.",
        "ATG_FoxO_CIS_dn": "Predicts a down-regulation related to the FoxO (Forkhead box O) cis-regulatory element.",
        "ATG_FoxO_CIS_up": "Predicts an up-regulation related to the FoxO (Forkhead box O) cis-regulatory element.",
        "ATG_GAL4_TRANS_dn": "Predicts a down-regulation related to the GAL4 transcriptional activity.",
        "ATG_GATA_CIS_dn": "Predicts a down-regulation related to the GATA cis-regulatory element.",
        "ATG_GATA_CIS_up": "Predicts an up-regulation related to the GATA cis-regulatory element.",
         "ATG_GLI_CIS_dn": "Predicts a down-regulation related to the GLI (Glioma-associated oncogene homolog) cis-regulatory element.",
        "ATG_GLI_CIS_up": "Predicts an up-regulation related to the GLI cis-regulatory element.",
        "ATG_GRE_CIS_dn": "Predicts a down-regulation related to the GRE (Glucocorticoid Response Element) cis-regulatory element.",
        "ATG_GRE_CIS_up": "Predicts an up-regulation related to the GRE cis-regulatory element.",
        "ATG_GR_TRANS_dn": "Predicts a down-regulation in the GR (Glucocorticoid Receptor) transcriptional activity.",
        "ATG_GR_TRANS_up": "Predicts an up-regulation in the GR transcriptional activity.",
        "ATG_HIF1a_CIS_dn": "Predicts a down-regulation related to the HIF1a (Hypoxia-inducible factor 1-alpha) cis-regulatory element.",
        "ATG_HIF1a_CIS_up": "Predicts an up-regulation related to the HIF1a cis-regulatory element.",
        "ATG_HNF4a_TRANS_dn": "Predicts a down-regulation in the HNF4a (Hepatocyte Nuclear Factor 4 Alpha) transcriptional activity.",
        "ATG_HNF4a_TRANS_up": "Predicts an up-regulation in the HNF4a transcriptional activity.",
        "ATG_HNF6_CIS_dn": "Predicts a down-regulation related to the HNF6 (Hepatocyte Nuclear Factor 6) cis-regulatory element.",
        "ATG_HNF6_CIS_up": "Predicts an up-regulation related to the HNF6 cis-regulatory element.",
        "ATG_HSE_CIS_dn": "Predicts a down-regulation related to the HSE (Heat Shock Element) cis-regulatory element.",
        "ATG_HSE_CIS_up": "Predicts an up-regulation related to the HSE cis-regulatory element.",
        "ATG_IR1_CIS_dn": "Predicts a down-regulation related to the IR1 (Insulin Response Element 1) cis-regulatory element.",
        "ATG_IR1_CIS_up": "Predicts an up-regulation related to the IR1 cis-regulatory element.",
        "ATG_ISRE_CIS_dn": "Predicts a down-regulation related to the ISRE (Interferon-Stimulated Response Element) cis-regulatory element.",
        "ATG_ISRE_CIS_up": "Predicts an up-regulation related to the ISRE cis-regulatory element.",
        "ATG_LXRa_TRANS_dn": "Predicts a down-regulation in the LXRa (Liver X Receptor Alpha) transcriptional activity.",
        "ATG_LXRa_TRANS_up": "Predicts an up-regulation in the LXRa transcriptional activity.",
         "ATG_LXRb_TRANS_dn": "Predicts a down-regulation in the LXRb (Liver X Receptor Beta) transcriptional activity.",
        "ATG_LXRb_TRANS_up": "Predicts an up-regulation in the LXRb transcriptional activity.",
        "ATG_MRE_CIS_up": "Predicts an up-regulation related to the MRE (Metal Response Element) cis-regulatory element.",
        "ATG_M_06_TRANS_up": "Predicts an up-regulation in the transcriptional activity related to M_06 target.",
        "ATG_M_19_CIS_dn": "Predicts a down-regulation related to the M_19 cis-regulatory element.",
        "ATG_M_19_TRANS_dn": "Predicts a down-regulation in the M_19 transcriptional activity.",
        "ATG_M_19_TRANS_up": "Predicts an up-regulation in the M_19 transcriptional activity.",
        "ATG_M_32_CIS_dn": "Predicts a down-regulation related to the M_32 cis-regulatory element.",
        "ATG_M_32_CIS_up": "Predicts an up-regulation related to the M_32 cis-regulatory element.",
        "ATG_M_32_TRANS_dn": "Predicts a down-regulation in the M_32 transcriptional activity.",
        "ATG_M_32_TRANS_up": "Predicts an up-regulation in the M_32 transcriptional activity.",
        "ATG_M_61_TRANS_up": "Predicts an up-regulation in the transcriptional activity related to M_61 target.",
        "ATG_Myb_CIS_dn": "Predicts a down-regulation related to the Myb (Myb proto-oncogene protein) cis-regulatory element.",
        "ATG_Myb_CIS_up": "Predicts an up-regulation related to the Myb cis-regulatory element.",
        "ATG_Myc_CIS_dn": "Predicts a down-regulation related to the Myc (Myc proto-oncogene protein) cis-regulatory element.",
        "ATG_Myc_CIS_up": "Predicts an up-regulation related to the Myc cis-regulatory element.",
        "ATG_NFI_CIS_dn": "Predicts a down-regulation related to the NFI (Nuclear Factor I) cis-regulatory element.",
        "ATG_NFI_CIS_up": "Predicts an up-regulation related to the NFI cis-regulatory element.",
        "ATG_NF_kB_CIS_dn": "Predicts a down-regulation related to the NF-kB (Nuclear Factor kappa B) cis-regulatory element.",
        "ATG_NF_kB_CIS_up": "Predicts an up-regulation related to the NF-kB cis-regulatory element.",
         "ATG_NRF1_CIS_dn": "Predicts a down-regulation related to the NRF1 (Nuclear Respiratory Factor 1) cis-regulatory element.",
        "ATG_NRF1_CIS_up": "Predicts an up-regulation related to the NRF1 cis-regulatory element.",
        "ATG_NRF2_ARE_CIS_dn": "Predicts a down-regulation related to the NRF2-ARE (Nuclear factor erythroid 2–Antioxidant Response Element) cis-regulatory element.",
        "ATG_NRF2_ARE_CIS_up": "Predicts an up-regulation related to the NRF2-ARE cis-regulatory element.",
        "ATG_NURR1_TRANS_dn": "Predicts a down-regulation in the NURR1 (Nuclear receptor related 1 protein) transcriptional activity.",
        "ATG_NURR1_TRANS_up": "Predicts an up-regulation in the NURR1 transcriptional activity.",
        "ATG_Oct_MLP_CIS_dn": "Predicts a down-regulation related to the Oct-MLP (Octamer Motif - Myelin-related Lipid Protein) cis-regulatory element.",
        "ATG_Oct_MLP_CIS_up": "Predicts an up-regulation related to the Oct-MLP cis-regulatory element.",
        "ATG_PBREM_CIS_dn": "Predicts a down-regulation related to the PBREM (Phenobarbital Response Element Module) cis-regulatory element.",
        "ATG_PBREM_CIS_up": "Predicts an up-regulation related to the PBREM cis-regulatory element.",
        "ATG_PPARa_TRANS_dn": "Predicts a down-regulation in the PPARa (Peroxisome proliferator-activated receptor alpha) transcriptional activity.",
        "ATG_PPARa_TRANS_up": "Predicts an up-regulation in the PPARa transcriptional activity.",
        "ATG_PPARd_TRANS_up": "Predicts an up-regulation in the PPARd (Peroxisome proliferator-activated receptor delta) transcriptional activity.",
        "ATG_PPARg_TRANS_up": "Predicts an up-regulation in the PPARg (Peroxisome proliferator-activated receptor gamma) transcriptional activity.",
        "ATG_PPRE_CIS_dn": "Predicts a down-regulation related to the PPRE (Peroxisome proliferator-activated receptor response element) cis-regulatory element.",
        "ATG_PPRE_CIS_up": "Predicts an up-regulation related to the PPRE cis-regulatory element.",
         "ATG_PXRE_CIS_dn": "Predicts a down-regulation related to the PXRE (Pregnane X Receptor Element) cis-regulatory element.",
        "ATG_PXRE_CIS_up": "Predicts an up-regulation related to the PXRE cis-regulatory element.",
        "ATG_PXR_TRANS_dn": "Predicts a down-regulation in the PXR (Pregnane X Receptor) transcriptional activity.",
        "ATG_PXR_TRANS_up": "Predicts an up-regulation in the PXR transcriptional activity.",
        "ATG_Pax6_CIS_up": "Predicts an up-regulation related to the Pax6 cis-regulatory element.",
        "ATG_RARa_TRANS_dn": "Predicts a down-regulation in the RARa (Retinoic Acid Receptor alpha) transcriptional activity.",
        "ATG_RARa_TRANS_up": "Predicts an up-regulation in the RARa transcriptional activity.",
        "ATG_RARb_TRANS_dn": "Predicts a down-regulation in the RARb (Retinoic Acid Receptor beta) transcriptional activity.",
        "ATG_RARb_TRANS_up": "Predicts an up-regulation in the RARb transcriptional activity.",
        "ATG_RARg_TRANS_dn": "Predicts a down-regulation in the RARg (Retinoic Acid Receptor gamma) transcriptional activity.",
        "ATG_RARg_TRANS_up": "Predicts an up-regulation in the RARg transcriptional activity.",
        "ATG_RORE_CIS_dn": "Predicts a down-regulation related to the RORE (Retinoid-related Orphan Receptor Element) cis-regulatory element.",
        "ATG_RORE_CIS_up": "Predicts an up-regulation related to the RORE cis-regulatory element.",
        "ATG_RORb_TRANS_dn": "Predicts a down-regulation in the RORb (Retinoid-related Orphan Receptor beta) transcriptional activity.",
        "ATG_RORg_TRANS_dn": "Predicts a down-regulation in the RORg (Retinoid-related Orphan Receptor gamma) transcriptional activity.",
        "ATG_RORg_TRANS_up": "Predicts an up-regulation in the RORg transcriptional activity.",
        "ATG_RXRa_TRANS_dn": "Predicts a down-regulation in the RXRa (Retinoid X Receptor alpha) transcriptional activity.",
        "ATG_RXRa_TRANS_up": "Predicts an up-regulation in the RXRa transcriptional activity.",
        "ATG_RXRb_TRANS_dn": "Predicts a down-regulation in the RXRb (Retinoid X Receptor beta) transcriptional activity.",
        "ATG_RXRb_TRANS_up": "Predicts an up-regulation in the RXRb transcriptional activity.",
        "ATG_SREBP_CIS_dn": "Predicts a down-regulation related to the SREBP (Sterol Regulatory Element-Binding Protein) cis-regulatory element.",
        "ATG_SREBP_CIS_up": "Predicts an up-regulation related to the SREBP cis-regulatory element.",
        "ATG_STAT3_CIS_dn": "Predicts a down-regulation related to the STAT3 (Signal Transducer and Activator of Transcription 3) cis-regulatory element.",
        "ATG_STAT3_CIS_up": "Predicts an up-regulation related to the STAT3 cis-regulatory element.",
        "ATG_Sox_CIS_dn": "Predicts a down-regulation related to the Sox (Sex-determining Region Y-box) cis-regulatory element.",
        "ATG_Sox_CIS_up": "Predicts an up-regulation related to the Sox cis-regulatory element.",
        "ATG_Sp1_CIS_dn": "Predicts a down-regulation related to the Sp1 (Specificity Protein 1) cis-regulatory element.",
        "ATG_Sp1_CIS_up": "Predicts an up-regulation related to the Sp1 cis-regulatory element.",
        "ATG_TAL_CIS_dn": "Predicts a down-regulation related to the TAL (T-cell Acute Lymphocytic Leukemia) cis-regulatory element.",
        "ATG_TAL_CIS_up": "Predicts an up-regulation related to the TAL cis-regulatory element.",
        "ATG_TA_CIS_dn": "Predicts a down-regulation related to the TA (Ternary Complex Factor) cis-regulatory element.",
        "ATG_TA_CIS_up": "Predicts an up-regulation related to the TA cis-regulatory element.",
        "ATG_TCF_b_cat_CIS_dn": "Predicts a down-regulation related to the TCF-b-cat (T-Cell Factor-beta-catenin) cis-regulatory element.",
        "ATG_TCF_b_cat_CIS_up": "Predicts an up-regulation related to the TCF-b-cat cis-regulatory element.",
        "ATG_TGFb_CIS_dn": "Predicts a down-regulation related to the TGFb (Transforming Growth Factor beta) cis-regulatory element.",
        "ATG_TGFb_CIS_up": "Predicts an up-regulation related to the TGFb cis-regulatory element.",
        "ATG_THRa1_TRANS_dn": "Predicts a down-regulation in the THRa1 (Thyroid Hormone Receptor alpha 1) transcriptional activity.",
        "ATG_THRa1_TRANS_up": "Predicts an up-regulation in the THRa1 transcriptional activity.",
         "BSK_LPS_VCAM1_down": "Represents the downregulation of VCAM1 due to LPS exposure in a specific bioassay.",
    "BSK_SAg_CD38_down": "Indicates the decrease in CD38 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_CD40_down": "Indicates the decrease in CD40 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_CD69_down": "Indicates the decrease in CD69 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_Eselectin_down": "Represents the downregulation of Eselectin due to superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_Eselectin_up": "Represents the upregulation of Eselectin due to superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_IL8_down": "Indicates the decrease in IL8 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_IL8_up": "Indicates the increase in IL8 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_MCP1_down": "Indicates the decrease in MCP1 expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_MIG_down": "Indicates the decrease in MIG expression following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_PBMCCytotoxicity_down": "Represents the cytotoxic effect on peripheral blood mononuclear cells (PBMC) due to superantigen (SAg) exposure, resulting in a decrease.",
    "BSK_SAg_PBMCCytotoxicity_up": "Represents the cytotoxic effect on peripheral blood mononuclear cells (PBMC) due to superantigen (SAg) exposure, resulting in an increase.",
    "BSK_SAg_Proliferation_down": "Represents the decrease in cell proliferation following superantigen (SAg) exposure in a specific bioassay.",
    "BSK_SAg_SRB_down": "Represents the downregulation of SRB due to superantigen (SAg) exposure in a specific bioassay.",
    "BSK_hDFCGF_CollagenIII_down": "Indicates the decrease in CollagenIII expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_EGFR_down": "Indicates the decrease in EGFR expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_EGFR_up": "Indicates the increase in EGFR expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_IL8_down": "Indicates the decrease in IL8 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_IP10_down": "Indicates the decrease in IP10 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_MCSF_down": "Indicates the decrease in MCSF expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_MIG_down": "Indicates the decrease in MIG expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_MMP1_down": "Indicates the decrease in MMP1 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_MMP1_up": "Indicates the increase in MMP1 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_PAI1_down": "Indicates the decrease in PAI1 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_Proliferation_down": "Represents the decrease in cell proliferation following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_SRB_down": "Represents the downregulation of SRB due to hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_TIMP1_down": "Indicates the decrease in TIMP1 expression following hDFCGF exposure in a specific bioassay.",
    "BSK_hDFCGF_VCAM1_down": "Represents the downregulation of VCAM1 due to hDFCGF exposure in a specific bioassay.",
    "CEETOX_H295R_11DCORT_dn": "Represents the downregulation in 11-Deoxycortisol in H295R assay due to exposure in CEETOX study.",

     "CEETOX_H295R_ANDR_dn": "Indicates the downregulation of Androgen in H295R assay due to exposure in CEETOX study.",
    "CEETOX_H295R_CORTISOL_dn": "Signifies the downregulation of Cortisol in H295R assay as a result of CEETOX exposure.",
    "CEETOX_H295R_DOC_dn": "Represents the decrease in DOC in H295R assay post CEETOX exposure.",
    "CEETOX_H295R_DOC_up": "Represents the increase in DOC in H295R assay post CEETOX exposure.",
    "CEETOX_H295R_ESTRADIOL_dn": "Indicates a decrease in Estradiol in the H295R assay due to CEETOX exposure.",
    "CEETOX_H295R_ESTRADIOL_up": "Indicates an increase in Estradiol in the H295R assay due to CEETOX exposure.",
    "CEETOX_H295R_ESTRONE_dn": "Signifies the downregulation of Estrone in H295R assay following CEETOX exposure.",
    "CEETOX_H295R_ESTRONE_up": "Signifies the upregulation of Estrone in H295R assay following CEETOX exposure.",
    "CEETOX_H295R_OHPREG_up": "Indicates an upregulation of OHPREG in the H295R assay post CEETOX study exposure.",
    "CEETOX_H295R_OHPROG_dn": "Represents the decrease in OHPROG in H295R assay following CEETOX exposure.",
    "CEETOX_H295R_OHPROG_up": "Represents the increase in OHPROG in H295R assay following CEETOX exposure.",
    "CEETOX_H295R_PROG_up": "Indicates upregulation of Progesterone in the H295R assay after CEETOX study exposure.",
    "CEETOX_H295R_TESTO_dn": "Represents downregulation of Testosterone in H295R assay due to CEETOX study exposure.",
    "CLD_ABCB1_48hr": "Indicates the reaction or expression level of ABCB1 gene in a Cellular Level Detection (CLD) assay after 48 hours.",
    "CLD_ABCG2_48hr": "Shows the response of ABCG2 gene in a CLD assay at the 48-hour mark.",
    "CLD_CYP1A1_24hr": "Measures the expression or activity of the CYP1A1 gene in CLD assay at 24 hours.",
    "CLD_CYP1A1_48hr": "Measures the expression or activity of the CYP1A1 gene in CLD assay at 48 hours.",
    "CLD_CYP1A1_6hr": "Indicates the response of the CYP1A1 gene in a CLD assay 6 hours post-exposure.",
    "CLD_CYP1A2_24hr": "Reflects the 24-hour response of the CYP1A2 gene in a CLD assay.",
    "CLD_CYP1A2_48hr": "Reflects the 48-hour response of the CYP1A2 gene in a CLD assay.",
    "CLD_CYP1A2_6hr": "Indicates the reaction of the CYP1A2 gene 6 hours into a CLD assay.",
    "CLD_CYP2B6_24hr": "Monitors the activity or expression of CYP2B6 gene in a CLD assay after 24 hours.",
    "CLD_CYP2B6_48hr": "Shows the activity or expression of CYP2B6 gene in CLD assay 48 hours post-exposure.",
    "CLD_CYP2B6_6hr": "Indicates the response of CYP2B6 gene in a CLD assay 6 hours after treatment.",
    "CLD_CYP3A4_24hr": "Represents the 24-hour response of the CYP3A4 gene in a CLD study.",
    "CLD_CYP3A4_48hr": "Details the expression or activity of the CYP3A4 gene in a CLD assay at the 48-hour mark.",
    "CLD_CYP3A4_6hr": "Reflects the 6-hour activity or expression level of CYP3A4 in a CLD assay.",
    "CLD_GSTA2_48hr": "Indicates the response of GSTA2 gene in CLD assay at 48 hours post-exposure.",
    "CLD_SULT2A_24hr": "Measures the 24-hour activity or response of the SULT2A gene in a CLD assay.",
    "CLD_SULT2A_48hr": "Represents the 48-hour activity of SULT2A in a CLD assay.",
    "CLD_UGT1A1_24hr": "Shows the expression or activity level of the UGT1A1 gene in a CLD assay after 24 hours.",
    "CLD_UGT1A1_48hr": "Details the expression of UGT1A1 gene 48 hours post-exposure in a CLD study.",
    "NCCT_HEK293T_CellTiterGLO": "Indicates the CellTiterGLO response in HEK293T cells under the National Center for Computational Toxicology (NCCT) guidelines.",
    "NCCT_QuantiLum_inhib_2_dn": "Reflects downregulation or inhibition in the QuantiLum assay under NCCT, type 2.",
    "NCCT_QuantiLum_inhib_dn": "Indicates downregulation or inhibition in the QuantiLum assay under NCCT guidelines.",
    "NCCT_TPO_AUR_dn": "Reflects downregulation in the Thyroid Peroxidase (TPO) assay with aurora kinase exposure under NCCT guidelines.",
    "NCCT_TPO_GUA_dn": "Indicates downregulation in the TPO assay with guanylate kinase exposure under NCCT guidelines.",
    "NHEERL_ZF_144hpf_TERATOSCORE_up": "Represents upregulation in the TERATOSCORE assay in Zebrafish (ZF) at 144 hours post-fertilization, as per NHEERL guidelines.",
    "NVS_ADME_hCYP19A1": "Represents the interaction or modulation of human CYP19A1 enzyme under the NVS ADME assay guidelines.",
    "NVS_ADME_hCYP1A1": "Details the interaction or response of human CYP1A1 enzyme in the NVS ADME study.",
    "NVS_ADME_hCYP1A2": "Indicates the activity or modulation of human CYP1A2 enzyme in the NVS ADME assay.",
    "NVS_ADME_hCYP2A6": "Measures the response or interaction of human CYP2A6 enzyme as per NVS ADME guidelines.",
    "NVS_ADME_hCYP2B6": "Represents the interaction or modulation of human CYP2B6 enzyme in the NVS ADME assay.",
    "NVS_ADME_hCYP2C19": "Details the response of human CYP2C19 enzyme under the NVS ADME study guidelines.",
    "NVS_ADME_hCYP2C9": "Indicates the modulation or activity of human CYP2C9 enzyme in the NVS ADME assay.",
    "NVS_ADME_hCYP2D6": "Represents the interaction or activity of human CYP2D6 enzyme in the NVS ADME study.",
    "NVS_ADME_hCYP3A4": "Indicates the response or modulation of human CYP3A4 enzyme as per NVS ADME guidelines.",
    "NVS_ADME_hCYP4F12": "Measures the interaction or modulation of human CYP4F12 enzyme in the NVS ADME assay.",
    "NVS_ADME_rCYP2C12": "Details the response or interaction of rat CYP2C12 enzyme under the NVS ADME guidelines.",
    "NVS_ENZ_hAChE": "Indicates the modulation or interaction with human Acetylcholinesterase enzyme in the NVS enzyme study.",
    "NVS_ENZ_hAMPKa1": "Reflects the activity or modulation of human AMPK alpha-1 enzyme in the NVS enzyme assay.",
    "NVS_ENZ_hAurA": "Indicates the response or interaction of human Aurora A kinase in the NVS enzyme study.",
    "NVS_ENZ_hBACE": "Details the modulation or activity of human Beta-Secretase enzyme in the NVS enzyme assay.",
    "NVS_ENZ_hCASP5": "Measures the response or interaction of human Caspase 5 enzyme as per NVS enzyme guidelines.",
    "NVS_ENZ_hCK1D": "Indicates the activity or modulation of human Casein Kinase 1 Delta in the NVS enzyme study.",
    "NVS_ENZ_hDUSP3": "Reflects the response or modulation of human Dual Specificity Phosphatase 3 in the NVS enzyme assay.",
    "NVS_ENZ_hES": "Indicates the interaction or response of human Estrogen enzyme in the NVS enzyme study.",
    "NVS_ENZ_hElastase": "Details the modulation or activity of human Elastase enzyme as per NVS enzyme guidelines.",
    "NVS_ENZ_hFGFR1": "Indicates the response or interaction of human Fibroblast Growth Factor Receptor 1 in the NVS enzyme assay.",
    "NVS_ENZ_hGSK3b": "Measures the modulation or activity of human Glycogen Synthase Kinase 3 Beta in the NVS enzyme study.",
    "NVS_ENZ_hMMP1": "Represents the response or interaction of human Matrix Metallopeptidase 1 in the NVS enzyme assay.",
     "NVS_ENZ_hMMP13": "Indicates the modulation or interaction with human Matrix Metallopeptidase 13 as measured in the NVS enzyme assay.",
    "NVS_ENZ_hMMP2": "Details the response or activity of human Matrix Metallopeptidase 2 under the NVS enzyme study.",
    "NVS_ENZ_hMMP3": "Describes the interaction or modulation of human Matrix Metallopeptidase 3 in the context of the NVS enzyme assay.",
    "NVS_ENZ_hMMP7": "Represents the activity or modulation of human Matrix Metallopeptidase 7 as measured in the NVS enzyme study.",
    "NVS_ENZ_hMMP9": "Captures the response or interaction of human Matrix Metallopeptidase 9 as per NVS enzyme guidelines.",
    "NVS_ENZ_hPDE10": "Indicates the activity or modulation of human Phosphodiesterase 10 in the NVS enzyme assay.",
    "NVS_ENZ_hPDE4A1": "Reflects the response or modulation of human Phosphodiesterase 4A1 in the NVS enzyme study.",
    "NVS_ENZ_hPDE5": "Denotes the interaction or activity of human Phosphodiesterase 5 under the NVS enzyme study guidelines.",
    "NVS_ENZ_hPI3Ka": "Signifies the modulation or response of human Phosphoinositide 3-Kinase alpha as per the NVS enzyme assay.",
    "NVS_ENZ_hPTEN": "Describes the interaction or modulation of human Phosphatase and tensin homolog in the NVS enzyme study.",
    "NVS_ENZ_hPTPN11": "Measures the response or activity of human Protein Tyrosine Phosphatase N11 in the NVS enzyme assay.",
    "NVS_ENZ_hPTPN12": "Reflects the modulation or interaction with human Protein Tyrosine Phosphatase N12 as studied under NVS enzyme guidelines.",
    "NVS_ENZ_hPTPN13": "Indicates the response or activity of human Protein Tyrosine Phosphatase N13 as per the NVS enzyme study.",
    "NVS_ENZ_hPTPN9": "Details the interaction or modulation of human Protein Tyrosine Phosphatase N9 in the context of the NVS enzyme assay.",
    "NVS_ENZ_hPTPRC": "Captures the modulation or response of human Protein Tyrosine Phosphatase Receptor Type C as studied in the NVS enzyme assay.",
    "NVS_ENZ_hSIRT1": "Signifies the interaction or activity of human Sirtuin 1 in the NVS enzyme study.",
    "NVS_ENZ_hSIRT2": "Details the response or modulation of human Sirtuin 2 under the NVS enzyme guidelines.",
    "NVS_ENZ_hTrkA": "Describes the activity or interaction of human Tropomyosin receptor kinase A in the context of the NVS enzyme study.",
    "NVS_ENZ_hVEGFR2": "Indicates the modulation or interaction with human Vascular Endothelial Growth Factor Receptor 2 as per the NVS enzyme assay.",
    "NVS_ENZ_oCOX1": "Denotes the response or activity of ovine Cyclooxygenase 1 under the NVS enzyme study guidelines.",
    "NVS_ENZ_oCOX2": "Captures the interaction or modulation of ovine Cyclooxygenase 2 in the NVS enzyme assay.",
    "NVS_ENZ_rAChE": "Reflects the modulation or interaction with rat Acetylcholinesterase as measured in the NVS enzyme study.",
    "NVS_ENZ_rCNOS": "Details the response or activity of rat Constitutive Nitric Oxide Synthase in the context of the NVS enzyme assay.",
    "NVS_ENZ_rMAOAC": "Describes the interaction or modulation of rat Monoamine Oxidase A in its cytoplasmic form under the NVS enzyme guidelines.",
     "NVS_ENZ_rMAOAP": "Signifies the response or modulation of rat Monoamine Oxidase A in its plasma membrane-bound form according to the NVS enzyme assay.",
    "NVS_ENZ_rMAOBC": "Indicates the activity or interaction of rat Monoamine Oxidase B in its cytoplasmic form, as measured in the NVS enzyme study.",
    "NVS_ENZ_rMAOBP": "Details the modulation or interaction with rat Monoamine Oxidase B in its plasma membrane-bound variant under NVS enzyme guidelines.",
    "NVS_ENZ_rabI2C": "Captures the response or activity of rabbit Isoform 2 of enzyme (specific enzyme to be determined based on actual context) in the NVS enzyme assay.",
    "NVS_GPCR_bAdoR_NonSelective": "Denotes the interaction or modulation of a non-selective beta Adenosine Receptor as studied in the NVS GPCR assay.",
    "NVS_GPCR_bDR_NonSelective": "Reflects the activity or interaction with a non-selective beta Dopamine Receptor under the NVS GPCR study guidelines.",
    "NVS_GPCR_g5HT4": "Indicates the modulation or response of gamma 5-Hydroxytryptamine Receptor 4 as per the NVS GPCR assay.",
    "NVS_GPCR_gH2": "Describes the interaction or activity of gamma Histamine 2 Receptor in the NVS GPCR study.",
    "NVS_GPCR_gLTB4": "Signifies the response or modulation of gamma Leukotriene B4 Receptor as measured in the NVS GPCR assay.",
    "NVS_GPCR_gLTD4": "Details the interaction or activity of gamma Leukotriene D4 Receptor under the NVS GPCR guidelines.",
    "NVS_GPCR_gMPeripheral_NonSelective": "Denotes the modulation or interaction with a non-selective gamma Muscarinic Peripheral Receptor as per NVS GPCR study.",
    "NVS_GPCR_gOpiateK": "Indicates the response or activity of gamma Opiate K Receptor in the context of the NVS GPCR assay.",
    "NVS_GPCR_h5HT2A": "Describes the interaction or activity of human 5-Hydroxytryptamine Receptor 2A as per the NVS GPCR assay.",
    "NVS_GPCR_h5HT5A": "Indicates the modulation or response of human 5-Hydroxytryptamine Receptor 5A in the NVS GPCR assay context.",
    "NVS_GPCR_h5HT6": "Captures the response or activity of human 5-Hydroxytryptamine Receptor 6 according to the NVS GPCR assay.",
    "NVS_GPCR_h5HT7": "Signifies the interaction or modulation of human 5-Hydroxytryptamine Receptor 7 as measured in the NVS GPCR study.",
    "NVS_GPCR_hAT1": "Reflects the activity or interaction with human Angiotensin II Receptor Type 1 under the NVS GPCR guidelines.",
    "NVS_GPCR_hAdoRA1": "Denotes the modulation or response of human Adenosine Receptor A1 as per the NVS GPCR study.",
    "NVS_GPCR_hAdoRA2a": "Details the response or interaction of human Adenosine Receptor A2a in the context of the NVS GPCR assay.",
    "NVS_GPCR_hAdra2A": "Captures the activity or modulation of human Adrenoceptor Alpha 2A according to the NVS GPCR study.",
    "NVS_GPCR_hAdra2C": "Indicates the interaction or modulation of human Adrenoceptor Alpha 2C in the NVS GPCR assay.",
    "NVS_GPCR_hAdrb1": "Details the activity or interaction of human Beta-1 Adrenergic Receptor under the NVS GPCR study guidelines.",
    "NVS_GPCR_hAdrb2": "Signifies the response or modulation of human Beta-2 Adrenergic Receptor as measured by the NVS GPCR assay.",
    "NVS_GPCR_hAdrb3": "Denotes the interaction or modulation of human Beta-3 Adrenergic Receptor as per the NVS GPCR guidelines.",
    "NVS_GPCR_hDRD1": "Captures the activity or response of human Dopamine Receptor D1 according to NVS GPCR study.",
    "NVS_GPCR_hDRD2s": "Indicates the interaction or modulation of human Dopamine Receptor D2 short form in the NVS GPCR assay.",
    "NVS_GPCR_hDRD4.4": "Details the modulation or activity of human Dopamine Receptor D4.4 under the NVS GPCR study guidelines.",
    "NVS_GPCR_hH1": "Reflects the interaction or response of human Histamine H1 Receptor according to the NVS GPCR assay.",
    "NVS_GPCR_hLTB4_BLT1": "Captures the modulation or activity of human Leukotriene B4 Receptor BLT1 as per NVS GPCR guidelines.",
    "NVS_GPCR_hM1": "Signifies the response or interaction of human Muscarinic Acetylcholine Receptor M1 in the NVS GPCR study.",
    "NVS_GPCR_hM2": "Indicates the modulation or activity of human Muscarinic Acetylcholine Receptor M2 as measured by the NVS GPCR assay.",
    "NVS_GPCR_hM3": "Details the interaction or modulation of human Muscarinic Acetylcholine Receptor M3 according to the NVS GPCR study guidelines.",
    "NVS_GPCR_hM4": "Captures the response or interaction of human Muscarinic Acetylcholine Receptor M4 in the NVS GPCR assay.",
    "NVS_GPCR_hNK2": "Denotes the activity or modulation of human Neurokinin Receptor 2 as per NVS GPCR guidelines.",
    "NVS_GPCR_hOpiate_D1": "Reflects the modulation or interaction of human Opiate D1 Receptor in the context of the NVS GPCR study.",
    "NVS_GPCR_hOpiate_mu": "Indicates the response or activity of human Mu Opioid Receptor according to the NVS GPCR assay.",
    "NVS_GPCR_hTXA2": "Details the interaction or activity of human Thromboxane A2 Receptor as measured by the NVS GPCR study.",
    "NVS_GPCR_p5HT2C": "Describes the interaction or activity of presumably a porcine 5-Hydroxytryptamine Receptor 2C in the NVS GPCR assay.",
    "NVS_GPCR_r5HT1_NonSelective": "Details the non-selective interaction or response of rodent 5-Hydroxytryptamine Receptor 1 as per the NVS GPCR study.",
    "NVS_GPCR_r5HT_NonSelective": "Denotes the non-selective modulation or activity of a rodent 5-Hydroxytryptamine Receptor in the NVS GPCR context.",
    "NVS_GPCR_rAdra1B": "Captures the response or interaction of rodent Adrenoceptor Alpha 1B based on the NVS GPCR assay guidelines.",
    "NVS_GPCR_rAdra1_NonSelective": "Reflects the non-selective interaction or activity of a rodent Adrenoceptor Alpha 1 in the NVS GPCR study.",
    "NVS_GPCR_rAdra2_NonSelective": "Signifies the non-selective modulation or interaction of a rodent Adrenoceptor Alpha 2 as per NVS GPCR guidelines.",
    "NVS_GPCR_rAdrb_NonSelective": "Details the non-selective response or activity of a rodent Beta Adrenergic Receptor under the NVS GPCR assay.",
    "NVS_GPCR_rNK1": "Denotes the interaction or modulation of rodent Neurokinin Receptor 1 based on the NVS GPCR study.",
    "NVS_GPCR_rNK3": "Reflects the activity or modulation of rodent Neurokinin Receptor 3 according to the NVS GPCR assay.",
    "NVS_GPCR_rOpiate_NonSelective": "Captures the non-selective response or interaction of a rodent Opiate Receptor in the NVS GPCR context.",
    "NVS_GPCR_rOpiate_NonSelectiveNa": "Indicates the non-selective modulation or activity of a rodent Opiate Receptor with a sodium channel component, as per the NVS GPCR study.",
    "NVS_GPCR_rSST": "Details the response or interaction of rodent Somatostatin Receptor based on the NVS GPCR guidelines.",
    "NVS_GPCR_rTRH": "Signifies the activity or interaction of rodent Thyrotropin-Releasing Hormone Receptor as measured in the NVS GPCR assay.",
    "NVS_GPCR_rV1": "Indicates the modulation or response of rodent Vasopressin Receptor 1 in the context of the NVS GPCR study.",
    "NVS_GPCR_rabPAF": "Reflects the interaction or activity of rodent Platelet-Activating Factor Receptor according to the NVS GPCR guidelines.",
    "NVS_GPCR_rmAdra2B": "Denotes the modulation or response of a rodent mouse-specific Adrenoceptor Alpha 2B in the NVS GPCR context.",
    "NVS_IC_hKhERGCh": "Captures the interaction or activity of human Ether-a-go-go-Related Gene Potassium Channel based on the NVS Ion Channel assay.",
    "NVS_IC_rCaBTZCHL": "Details the response or modulation of rodent Calcium Channel with a specific marker, as per the NVS Ion Channel study.",
    "NVS_IC_rCaDHPRCh_L": "Signifies the activity or interaction of rodent Calcium Channel, Dihydropyridine Receptor, L-type, according to the NVS Ion Channel guidelines.",
    "NVS_IC_rNaCh_site2": "Indicates the interaction or activity at site 2 of a rodent Sodium Channel under the NVS Ion Channel assay.",
    "NVS_LGIC_bGABARa1": "Reflects the modulation or response of bovine Gamma-Aminobutyric Acid Receptor Alpha 1 based on the NVS Ligand-Gated Ion Channel study.",
    "NVS_LGIC_h5HT3": "Denotes the activity or interaction of human 5-Hydroxytryptamine Receptor 3 in the context of the NVS Ligand-Gated Ion Channel assay.",
    "NVS_LGIC_hNNR_NBungSens": "Captures the response or modulation of human Nicotinic Acetylcholine Receptor sensitive to Alpha-Bungarotoxin according to the NVS Ligand-Gated Ion Channel guidelines.",
    "NVS_LGIC_rGABAR_NonSelective": "Details the non-selective activity or interaction of a rodent Gamma-Aminobutyric Acid Receptor in the NVS Ligand-Gated Ion Channel study.",
    "NVS_LGIC_rNNR_BungSens": "Signifies the modulation or interaction of rodent Nicotinic Acetylcholine Receptor sensitive to Alpha-Bungarotoxin based on the NVS Ligand-Gated Ion Channel assay.",
     "NVS_MP_hPBR": "Describes the interaction or modulation of human Peripheral Benzodiazepine Receptor based on the NVS Membrane Protein assay.",
    "NVS_MP_rPBR": "Details the activity or interaction of rodent Peripheral Benzodiazepine Receptor in the context of the NVS Membrane Protein study.",
    "NVS_NR_bER": "Indicates the modulation or response of bovine Estrogen Receptor according to the NVS Nuclear Receptor assay guidelines.",
    "NVS_NR_bPR": "Captures the interaction or activity of bovine Progesterone Receptor based on the NVS Nuclear Receptor study.",
    "NVS_NR_cAR": "Signifies the modulation or response of canine Androgen Receptor in the NVS Nuclear Receptor assay.",
    "NVS_NR_hAR": "Denotes the interaction or activity of human Androgen Receptor under the NVS Nuclear Receptor assay guidelines.",
    "NVS_NR_hCAR_Antagonist": "Describes the antagonistic activity or interaction of human Constitutive Androstane Receptor in the context of the NVS Nuclear Receptor study.",
    "NVS_NR_hER": "Details the response or modulation of human Estrogen Receptor as per the NVS Nuclear Receptor guidelines.",
    "NVS_NR_hFXR_Agonist": "Reflects the agonistic activity or interaction of human Farnesoid X Receptor under the NVS Nuclear Receptor assay.",
    "NVS_NR_hFXR_Antagonist": "Indicates the antagonistic modulation or response of human Farnesoid X Receptor according to the NVS Nuclear Receptor study.",
    "NVS_NR_hGR": "Captures the interaction or modulation of human Glucocorticoid Receptor in the NVS Nuclear Receptor context.",
    "NVS_NR_hPPARa": "Signifies the activity or interaction of human Peroxisome Proliferator-Activated Receptor alpha as measured in the NVS Nuclear Receptor assay.",
    "NVS_NR_hPPARg": "Denotes the modulation or response of human Peroxisome Proliferator-Activated Receptor gamma based on the NVS Nuclear Receptor study.",
    "NVS_NR_hPR": "Details the interaction or activity of human Progesterone Receptor in the context of the NVS Nuclear Receptor assay.",
    "NVS_NR_hPXR": "Reflects the modulation or response of human Pregnane X Receptor according to the NVS Nuclear Receptor guidelines.",
    "NVS_NR_hRAR_Antagonist": "Indicates the antagonistic activity or interaction of human Retinoic Acid Receptor in the NVS Nuclear Receptor context.",
    "NVS_NR_hRARa_Agonist": "Captures the agonistic response or modulation of human Retinoic Acid Receptor alpha as per the NVS Nuclear Receptor study.",
    "NVS_NR_hTRa_Antagonist": "Denotes the antagonistic activity or interaction of human Thyroid Hormone Receptor alpha based on the NVS Nuclear Receptor assay guidelines.",
    "NVS_NR_mERa": "Details the response or interaction of murine Estrogen Receptor alpha in the NVS Nuclear Receptor context.",
    "NVS_NR_rAR": "Reflects the modulation or activity of rodent Androgen Receptor under the NVS Nuclear Receptor study.",
    "NVS_NR_rMR": "Signifies the interaction or response of rodent Mineralocorticoid Receptor as measured in the NVS Nuclear Receptor assay.",
    "NVS_OR_gSIGMA_NonSelective": "Indicates the non-selective modulation or interaction of a guinea pig Sigma Receptor in the NVS Orphan Receptor context.",
    "NVS_TR_gDAT": "Captures the activity or interaction of guinea pig Dopamine Transporter based on the NVS Transporter study.",
    "NVS_TR_hAdoT": "Denotes the response or modulation of human Adenosine Transporter as per the NVS Transporter guidelines.",
    "NVS_TR_hDAT": "Details the activity or interaction of human Dopamine Transporter in the context of the NVS Transporter assay.",
     "NVS_TR_hNET": "Describes the interaction or modulation of the human Norepinephrine Transporter according to the NVS Transporter study.",
    "NVS_TR_hSERT": "Indicates the activity or interaction with the human Serotonin Transporter based on the NVS Transporter assay guidelines.",
    "NVS_TR_rNET": "Captures the response or modulation of rodent Norepinephrine Transporter in the NVS Transporter context.",
    "NVS_TR_rSERT": "Reflects the interaction or activity of rodent Serotonin Transporter under the NVS Transporter study.",
    "NVS_TR_rVMAT2": "Signifies the modulation or response of rodent Vesicular Monoamine Transporter 2 as measured in the NVS Transporter assay.",
    "OT_AR_ARELUC_AG_1440": "Denotes the results from an OT Androgen Receptor assay using a LUC reporter gene, with AG as the substrate and 1440 as a potential parameter or condition.",
    "OT_AR_ARSRC1_0480": "Details the findings from an OT Androgen Receptor study involving the SRC1 coactivator and 0480 as a potential parameter or condition.",
    "OT_AR_ARSRC1_0960": "Indicates the results from an OT Androgen Receptor assay involving the SRC1 coactivator and 0960 as a specific parameter or condition.",
    "OT_ER_ERaERa_0480": "Details the interaction or modulation of Estrogen Receptor alpha in an OT assay with 0480 as a defining condition.",
    "OT_ER_ERaERa_1440": "Captures the activity or interaction of Estrogen Receptor alpha in an OT assay, with 1440 as a specific parameter or condition.",
    "OT_ER_ERaERb_0480": "Reflects the results of an OT assay focusing on both Estrogen Receptor alpha and beta, with 0480 as a defining condition.",
    "OT_ER_ERaERb_1440": "Signifies the interaction or response in an OT assay that studies both Estrogen Receptor alpha and beta, with 1440 as a parameter or condition.",
    "OT_ER_ERbERb_0480": "Details the results from an OT assay focusing solely on Estrogen Receptor beta, with 0480 as a specific condition.",
    "OT_ER_ERbERb_1440": "Indicates the findings from an OT assay examining Estrogen Receptor beta, with 1440 as a defining parameter or condition.",
    "OT_ERa_EREGFP_0120": "Captures the activity or interaction of Estrogen Receptor alpha in an OT assay using a GFP reporter, with 0120 as a condition or parameter.",
    "OT_ERa_EREGFP_0480": "Describes the results of an OT assay focusing on Estrogen Receptor alpha using a GFP reporter, with 0480 as a specific condition.",
    "OT_FXR_FXRSRC1_0480": "Reflects the modulation or activity of Farnesoid X Receptor in an OT study involving the SRC1 coactivator and 0480 as a condition or parameter.",
    "OT_FXR_FXRSRC1_1440": "Indicates the results of an OT assay examining Farnesoid X Receptor with the SRC1 coactivator and 1440 as a specific condition.",
    "OT_NURR1_NURR1RXRa_0480": "Denotes the findings from an OT assay focusing on NURR1 interaction with Retinoid X Receptor alpha, with 0480 as a defining condition.",
    "OT_NURR1_NURR1RXRa_1440": "Details the results from an OT assay studying the interaction of NURR1 with Retinoid X Receptor alpha, and 1440 as a specific parameter.",
    "TOX21_ARE_BLA_Agonist_ch1": "Reflects the agonistic activity in a TOX21 assay focusing on the Antioxidant Response Element, using a beta-lactamase reporter in channel 1.",
    "TOX21_ARE_BLA_Agonist_ch2": "Details the agonistic response in a TOX21 assay involving the Antioxidant Response Element, with a beta-lactamase reporter in channel 2.",
    "TOX21_ARE_BLA_agonist_ratio": "Indicates the ratio of agonistic activity for the Antioxidant Response Element in a TOX21 assay using a beta-lactamase reporter.",
    "TOX21_ARE_BLA_agonist_viability": "Captures the viability measurements in an agonist-based TOX21 assay focusing on the Antioxidant Response Element, using a beta-lactamase reporter.",
      "TOX21_AR_BLA_Agonist_ch1": "Denotes the results from a TOX21 assay examining the agonistic activity on the Androgen Receptor, using a beta-lactamase reporter in channel 1.",
    "TOX21_AR_BLA_Agonist_ch2": "Reflects the agonistic response of the Androgen Receptor in a TOX21 assay with a beta-lactamase reporter in channel 2.",
    "TOX21_AR_BLA_Agonist_ratio": "Represents the ratio of agonistic activity on the Androgen Receptor in a TOX21 assay, using a beta-lactamase reporter system.",
    "TOX21_AR_BLA_Antagonist_ch1": "Details the antagonistic activity of the Androgen Receptor in a TOX21 assay with a beta-lactamase reporter, recorded in channel 1.",
    "TOX21_AR_BLA_Antagonist_ch2": "Signifies the results of the antagonistic response of the Androgen Receptor in a TOX21 assay, using a beta-lactamase reporter in channel 2.",
    "TOX21_AR_BLA_Antagonist_ratio": "Indicates the ratio of antagonistic activity on the Androgen Receptor in a TOX21 assay, using the beta-lactamase reporter.",
    "TOX21_AR_BLA_Antagonist_viability": "Reports the viability measurements related to the antagonistic activity on the Androgen Receptor in a TOX21 assay using a beta-lactamase reporter.",
    "TOX21_AR_LUC_MDAKB2_Agonist": "Denotes the agonistic response in a TOX21 assay focusing on the Androgen Receptor, using a luciferase reporter in the MDA-KB2 cell line.",
    "TOX21_AR_LUC_MDAKB2_Antagonist": "Details the antagonistic response on the Androgen Receptor in a TOX21 assay with a luciferase reporter system in the MDA-KB2 cell line.",
    "TOX21_AR_LUC_MDAKB2_Antagonist2": "Reflects another (potentially varying condition or measurement) antagonistic activity for the Androgen Receptor in a TOX21 assay with a luciferase reporter, using the MDA-KB2 cell line.",
    "TOX21_AhR_LUC_Agonist": "Indicates the agonistic activity on the Aryl Hydrocarbon Receptor in a TOX21 assay utilizing a luciferase reporter.",
    "TOX21_Aromatase_Inhibition": "Reports results from a TOX21 assay that measures the inhibitory activity on aromatase, an enzyme crucial for the synthesis of estrogen.",
    
        "TOX21_AutoFluor_HEK293_Cell_blue": "Measures autofluorescence in HEK293 cells, specifically capturing the blue spectrum.",
    "TOX21_AutoFluor_HEK293_Media_blue": "Measures autofluorescence in the media of cultured HEK293 cells, focusing on the blue spectrum.",
    "TOX21_AutoFluor_HEPG2_Cell_blue": "Reports autofluorescence in HEPG2 cells, with an emphasis on the blue spectrum.",
    "TOX21_AutoFluor_HEPG2_Cell_green": "Represents autofluorescence in HEPG2 cells, capturing the green spectrum.",
    "TOX21_AutoFluor_HEPG2_Media_blue": "Describes autofluorescence in the media of cultured HEPG2 cells in the blue spectrum.",
    "TOX21_AutoFluor_HEPG2_Media_green": "Indicates autofluorescence in the media of HEPG2 cells, focusing on the green spectrum.",
    "TOX21_ELG1_LUC_Agonist": "Measures agonistic activity using an ELG1 luciferase reporter assay.",
    "TOX21_ERa_BLA_Agonist_ch1": "Denotes the agonistic response on the Estrogen Receptor alpha using a beta-lactamase reporter in channel 1.",
    "TOX21_ERa_BLA_Agonist_ch2": "Represents the agonistic activity on the Estrogen Receptor alpha with a beta-lactamase reporter in channel 2.",
    "TOX21_ERa_BLA_Agonist_ratio": "Provides the ratio of agonistic response on the Estrogen Receptor alpha using a beta-lactamase reporting system.",
    "TOX21_ERa_BLA_Antagonist_ch1": "Details the antagonistic activity on the Estrogen Receptor alpha, recorded using a beta-lactamase reporter in channel 1.",
    "TOX21_ERa_BLA_Antagonist_ch2": "Reflects the antagonistic activity on the Estrogen Receptor alpha with a beta-lactamase reporter in channel 2.",
    "TOX21_ERa_BLA_Antagonist_ratio": "Provides the ratio of antagonistic response on the Estrogen Receptor alpha with the beta-lactamase reporter.",
    "TOX21_ERa_BLA_Antagonist_viability": "Describes viability measures related to the antagonistic activity on the Estrogen Receptor alpha using a beta-lactamase reporter.",
    "TOX21_ERa_LUC_BG1_Agonist": "Reports agonistic activity on the Estrogen Receptor alpha in a luciferase-based assay using the BG1 cell line.",
    "TOX21_ERa_LUC_BG1_Antagonist": "Details the antagonistic response on the Estrogen Receptor alpha using a luciferase reporting system in the BG1 cell line.",
    "TOX21_ESRE_BLA_ch1": "Reflects the response in an Estrogen Response Element-based assay using a beta-lactamase reporter in channel 1.",
    "TOX21_ESRE_BLA_ch2": "Indicates the results from an Estrogen Response Element-based assay with a beta-lactamase reporter in channel 2.",
    "TOX21_ESRE_BLA_ratio": "Shows the ratio of responses in an Estrogen Response Element-based assay using the beta-lactamase reporting system.",
    "TOX21_ESRE_BLA_viability": "Provides viability metrics from an Estrogen Response Element-based assay using a beta-lactamase reporter.",
    
        "TOX21_FXR_BLA_Antagonist_ch1": "Details the antagonistic activity related to the Farnesoid X Receptor (FXR) measured using a beta-lactamase reporter in channel 1.",
    "TOX21_FXR_BLA_Antagonist_ch2": "Represents the FXR antagonistic activity using a beta-lactamase reporter in channel 2.",
    "TOX21_FXR_BLA_agonist_ch2": "Reports the agonistic activity on the FXR using a beta-lactamase reporter in channel 2.",
    "TOX21_FXR_BLA_agonist_ratio": "Provides the ratio of agonistic activity for the FXR using a beta-lactamase reporting system.",
    "TOX21_FXR_BLA_antagonist_ratio": "Describes the ratio of antagonistic activity against FXR recorded with the beta-lactamase reporter.",
    "TOX21_FXR_BLA_antagonist_viability": "Denotes viability measurements related to the antagonistic activity on FXR via a beta-lactamase reporting system.",
    "TOX21_GR_BLA_Agonist_ch1": "Details the agonistic activity on the Glucocorticoid Receptor (GR) using a beta-lactamase reporter in channel 1.",
    "TOX21_GR_BLA_Agonist_ch2": "Indicates the agonistic activity on the GR measured using a beta-lactamase reporter in channel 2.",
    "TOX21_GR_BLA_Agonist_ratio": "Reports the ratio of agonistic activity for the GR using the beta-lactamase reporter.",
    "TOX21_GR_BLA_Antagonist_ch2": "Represents the antagonistic activity against the GR recorded with a beta-lactamase reporter in channel 2.",
    "TOX21_GR_BLA_Antagonist_ratio": "Provides the ratio of antagonistic activity for the GR based on a beta-lactamase reporting system.",
    "TOX21_GR_BLA_Antagonist_viability": "Describes viability measurements linked with antagonistic activities on the GR via the beta-lactamase reporter.",
    "TOX21_HSE_BLA_agonist_ch1": "Measures agonistic activity through a Heat Shock Element (HSE) pathway using a beta-lactamase reporter in channel 1.",
    "TOX21_HSE_BLA_agonist_ch2": "Represents the agonistic activity via the HSE pathway with a beta-lactamase reporter in channel 2.",
    "TOX21_HSE_BLA_agonist_ratio": "Shows the ratio of responses from an HSE-based assay using the beta-lactamase reporting system.",
    "TOX21_HSE_BLA_agonist_viability": "Details viability metrics from an HSE pathway-focused assay using a beta-lactamase reporter.",
    "TOX21_MMP_ratio_down": "Indicates the ratio of decreased activity in the Matrix Metalloproteinases (MMP) assay.",
    "TOX21_MMP_ratio_up": "Shows the ratio of increased activity in the MMP assay.",
    "TOX21_MMP_viability": "Provides a measure of cell viability in the context of the MMP assay.",
    "TOX21_NFkB_BLA_agonist_ch1": "Details the agonistic activity on the Nuclear Factor kappa B (NF-kB) pathway using a beta-lactamase reporter in channel 1.",
    
     "TOX21_NFkB_BLA_agonist_ch2": "Describes the agonistic activity on the Nuclear Factor kappa B (NF-kB) pathway using a beta-lactamase reporter in channel 2.",
    "TOX21_NFkB_BLA_agonist_ratio": "Provides the ratio of agonistic activity for the NF-kB using the beta-lactamase reporter.",
    "TOX21_NFkB_BLA_agonist_viability": "Indicates viability measurements associated with agonistic activity on the NF-kB pathway using a beta-lactamase reporting system.",
    "TOX21_PPARd_BLA_Agonist_viability": "Represents cell viability in response to agonists targeting Peroxisome Proliferator-Activated Receptor delta (PPARd) via a beta-lactamase assay.",
    "TOX21_PPARd_BLA_Antagonist_ch1": "Measures the antagonistic activity against the PPARd using a beta-lactamase reporter in channel 1.",
    "TOX21_PPARd_BLA_agonist_ch1": "Details the agonistic activity on PPARd using a beta-lactamase reporter in channel 1.",
    "TOX21_PPARd_BLA_agonist_ch2": "Indicates the agonistic activity on PPARd recorded with a beta-lactamase reporter in channel 2.",
    "TOX21_PPARd_BLA_agonist_ratio": "Describes the ratio of agonistic activity for the PPARd based on a beta-lactamase reporting system.",
    "TOX21_PPARd_BLA_antagonist_ratio": "Shows the ratio of antagonistic activity against PPARd using the beta-lactamase reporter.",
    "TOX21_PPARd_BLA_antagonist_viability": "Provides a measure of cell viability in the context of PPARd antagonistic activity through a beta-lactamase assay.",
    "TOX21_PPARg_BLA_Agonist_ch1": "Represents the agonistic activity on Peroxisome Proliferator-Activated Receptor gamma (PPARg) using a beta-lactamase reporter in channel 1.",
    "TOX21_PPARg_BLA_Agonist_ch2": "Details the agonistic activity on the PPARg pathway recorded with a beta-lactamase reporter in channel 2.",
    "TOX21_PPARg_BLA_Agonist_ratio": "Shows the ratio of agonistic responses for the PPARg using a beta-lactamase reporting system.",
    "TOX21_PPARg_BLA_Antagonist_ch1": "Indicates the antagonistic activity against the PPARg pathway via a beta-lactamase reporter in channel 1.",
    "TOX21_PPARg_BLA_antagonist_ratio": "Measures the ratio of antagonistic activity against PPARg recorded with the beta-lactamase reporter.",
    "TOX21_PPARg_BLA_antagonist_viability": "Details viability metrics related to PPARg antagonistic activity using a beta-lactamase reporting system.",
    "TOX21_TR_LUC_GH3_Agonist": "Represents an assay measuring the agonistic activity on Thyroid Receptor (TR) using a luciferase reporter in GH3 cells.",
    "TOX21_TR_LUC_GH3_Antagonist": "Provides information on the antagonistic activity against TR measured using a luciferase reporter system in GH3 cells.",
    "TOX21_VDR_BLA_Agonist_viability": "Indicates cell viability in response to agonists targeting the Vitamin D Receptor (VDR) through a beta-lactamase assay.",
    "TOX21_VDR_BLA_Antagonist_ch1": "Measures the antagonistic activity against the VDR using a beta-lactamase reporter in channel 1.",

  "TOX21_VDR_BLA_agonist_ch2": "Details the agonistic activity on the Vitamin D Receptor (VDR) pathway using a beta-lactamase reporter in channel 2.",
    "TOX21_VDR_BLA_agonist_ratio": "Describes the ratio of agonistic activity for the VDR using a beta-lactamase reporting system.",
    "TOX21_VDR_BLA_antagonist_ratio": "Measures the ratio of antagonistic activity against the VDR through the beta-lactamase reporter.",
    "TOX21_VDR_BLA_antagonist_viability": "Indicates cell viability metrics related to VDR antagonistic activity via the beta-lactamase reporter assay.",
    "TOX21_p53_BLA_p1_ch1": "Presents the activity of the p53 pathway, specifically the first phase, recorded using a beta-lactamase reporter in channel 1.",
    "TOX21_p53_BLA_p1_ch2": "Reports the activity of the p53 pathway during its first phase, using a beta-lactamase reporter in channel 2.",
    "TOX21_p53_BLA_p1_ratio": "Gives the ratio of activity for the first phase of the p53 pathway, determined via a beta-lactamase reporting system.",
    "TOX21_p53_BLA_p1_viability": "Provides an understanding of cell viability in relation to the activity of the p53 pathway's first phase, based on a beta-lactamase assay.",
    "TOX21_p53_BLA_p2_ch1": "Details the activity of the p53 pathway's second phase, as measured by a beta-lactamase reporter in channel 1.",
    "TOX21_p53_BLA_p2_ch2": "Describes the activity on the p53 pathway during its second phase, via a beta-lactamase reporter in channel 2.",
    "TOX21_p53_BLA_p2_ratio": "Shows the activity ratio for the p53 pathway's second phase, derived from a beta-lactamase reporting system.",
    "TOX21_p53_BLA_p2_viability": "Indicates cell viability metrics tied to the activity of the p53 pathway's second phase, using the beta-lactamase reporter.",
    "TOX21_p53_BLA_p3_ch1": "Presents the activity of the p53 pathway's third phase, recorded through a beta-lactamase reporter in channel 1.",
    "TOX21_p53_BLA_p3_ch2": "Gives information on the activity of the p53 pathway during its third phase, measured using a beta-lactamase reporter in channel 2.",
    "TOX21_p53_BLA_p3_ratio": "Describes the ratio of activity for the p53 pathway's third phase, determined via a beta-lactamase reporting method.",
    "TOX21_p53_BLA_p3_viability": "Indicates cell viability related to the activity of the third phase of the p53 pathway, based on a beta-lactamase reporter.",

 "TOX21_p53_BLA_p4_ch1": "Details the activity of the fourth phase of the p53 pathway as measured by a beta-lactamase reporter in channel 1.",
    "TOX21_p53_BLA_p4_ch2": "Highlights the activity of the p53 pathway during its fourth phase via a beta-lactamase reporter in channel 2.",
    "TOX21_p53_BLA_p4_ratio": "Provides a ratio representing the activity for the fourth phase of the p53 pathway, obtained through the beta-lactamase reporting method.",
    "TOX21_p53_BLA_p4_viability": "Describes the cell viability metrics in association with the activity of the p53 pathway's fourth phase, measured via the beta-lactamase reporter.",
    "TOX21_p53_BLA_p5_ch1": "Sheds light on the activity of the p53 pathway's fifth phase, using a beta-lactamase reporter in channel 1.",
    "TOX21_p53_BLA_p5_ch2": "Signifies the activity of the p53 pathway during its fifth phase through a beta-lactamase reporter in channel 2.",
    "TOX21_p53_BLA_p5_ratio": "Presents the activity ratio for the fifth phase of the p53 pathway, derived from the beta-lactamase reporting system.",
    "TOX21_p53_BLA_p5_viability": "Indicates the cell viability related to the activity of the fifth phase of the p53 pathway, captured using the beta-lactamase reporter method.",
    "Tanguay_ZF_120hpf_AXIS_up": "Represents an assay related to zebrafish (ZF) development at 120 hours post-fertilization, focusing on changes in the axis.",
    "Tanguay_ZF_120hpf_ActivityScore": "Provides a score detailing the activity or behavior of zebrafish larvae at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_BRAI_up": "Denotes an assay measuring changes or disruptions in zebrafish brain development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_CFIN_up": "Describes findings related to zebrafish caudal fin development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_CIRC_up": "Highlights observations pertaining to zebrafish circulatory system development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_EYE_up": "Sheds light on assays focused on zebrafish eye development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_JAW_up": "Denotes changes or disruptions in zebrafish jaw development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_MORT_up": "Indicates mortality rates or metrics in zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_OTIC_up": "Represents an assay related to the otic (ear) development of zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_PE_up": "Details observations about zebrafish pectoral fin evolution at 120 hours post-fertilization.",
    
     "Tanguay_ZF_120hpf_PFIN_up": "Captures details about the zebrafish's pelvic fin development at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_PIG_up": "Highlights findings related to pigmentation or coloration changes in zebrafish larvae at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_SNOU_up": "Presents observations on the development or abnormalities of the snout in zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_SOMI_up": "Details any changes or observations in the somite (segments in the early embryo) development of zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_SWIM_up": "Indicates behaviors or abnormalities related to swimming patterns in zebrafish larvae at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_TRUN_up": "Describes observations on the trunk development in zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_TR_up": "Focuses on the thymus and thyroid development or related abnormalities in zebrafish at 120 hours post-fertilization.",
    "Tanguay_ZF_120hpf_YSE_up": "Highlights observations related to yolk sac edema, a condition where fluid accumulates in the yolk sac of zebrafish larvae, at 120 hours post-fertilization.",

  "APR_HepG2_MicrotubuleCSK_24h_dn": "Profile for HepG2 cells with Microtubule CSK alteration after 24 hours (downregulated)",
  "APR_HepG2_MicrotubuleCSK_24h_up": "Profile for HepG2 cells with Microtubule CSK alteration after 24 hours (upregulated)",
  "APR_HepG2_MicrotubuleCSK_72h_dn": "Profile for HepG2 cells with Microtubule CSK alteration after 72 hours (downregulated)",
  "APR_HepG2_MicrotubuleCSK_72h_up": "Profile for HepG2 cells with Microtubule CSK alteration after 72 hours (upregulated)",
  "APR_HepG2_MitoticArrest_24h_up": "Profile for HepG2 cells showing Mitotic Arrest after 24 hours (upregulated)",
  "APR_HepG2_MitoticArrest_72h_up": "Profile for HepG2 cells showing Mitotic Arrest after 72 hours (upregulated)",
  "APR_HepG2_NuclearSize_24h_dn": "Profile for HepG2 cells with altered Nuclear Size after 24 hours (downregulated)",
  "APR_HepG2_NuclearSize_72h_dn": "Profile for HepG2 cells with altered Nuclear Size after 72 hours (downregulated)",
  "APR_HepG2_NuclearSize_72h_up": "Profile for HepG2 cells with altered Nuclear Size after 72 hours (upregulated)",

 "APR_HepG2_OxidativeStress_24h_up": "Profile for HepG2 cells under Oxidative Stress after 24 hours (upregulated)",
  "APR_HepG2_OxidativeStress_72h_up": "Profile for HepG2 cells under Oxidative Stress after 72 hours (upregulated)",
  "APR_HepG2_StressKinase_1h_up": "Profile for HepG2 cells with Stress Kinase alteration after 1 hour (upregulated)",
  "APR_HepG2_StressKinase_24h_up": "Profile for HepG2 cells with Stress Kinase alteration after 24 hours (upregulated)",
  "APR_HepG2_StressKinase_72h_up": "Profile for HepG2 cells with Stress Kinase alteration after 72 hours (upregulated)",
  "APR_HepG2_p53Act_24h_up": "Profile for HepG2 cells with p53 Activity after 24 hours (upregulated)",
  "APR_HepG2_p53Act_72h_up": "Profile for HepG2 cells with p53 Activity after 72 hours (upregulated)",
  "APR_Hepat_Apoptosis_24hr_up": "Profile for Hepatocytes undergoing Apoptosis after 24 hours (upregulated)",
  "APR_Hepat_Apoptosis_48hr_up": "Profile for Hepatocytes undergoing Apoptosis after 48 hours (upregulated)",
  "APR_Hepat_CellLoss_24hr_dn": "Profile for Hepatocytes with Cell Loss after 24 hours (downregulated)",
  "APR_Hepat_CellLoss_48hr_dn": "Profile for Hepatocytes with Cell Loss after 48 hours (downregulated)",
  "APR_Hepat_DNADamage_24hr_up": "Profile for Hepatocytes with DNA Damage after 24 hours (upregulated)",

 "APR_Hepat_DNADamage_48hr_up": "Profile for Hepatocytes with DNA Damage after 48 hours (upregulated)",
  "APR_Hepat_DNATexture_24hr_up": "Profile for Hepatocytes with altered DNA Texture after 24 hours (upregulated)",
  "APR_Hepat_DNATexture_48hr_up": "Profile for Hepatocytes with altered DNA Texture after 48 hours (upregulated)",
  "APR_Hepat_MitoFxnI_1hr_dn": "Profile for Hepatocytes with Mitochondrial Function I alteration after 1 hour (downregulated)",
  "APR_Hepat_MitoFxnI_24hr_dn": "Profile for Hepatocytes with Mitochondrial Function I alteration after 24 hours (downregulated)",
  "APR_Hepat_MitoFxnI_48hr_dn": "Profile for Hepatocytes with Mitochondrial Function I alteration after 48 hours (downregulated)",
  "APR_Hepat_NuclearSize_24hr_dn": "Profile for Hepatocytes with altered Nuclear Size after 24 hours (downregulated)",
  "APR_Hepat_NuclearSize_48hr_dn": "Profile for Hepatocytes with altered Nuclear Size after 48 hours (downregulated)",
  "APR_Hepat_Steatosis_24hr_up": "Profile for Hepatocytes displaying Steatosis after 24 hours (upregulated)",
  "APR_Hepat_Steatosis_48hr_up": "Profile for Hepatocytes displaying Steatosis after 48 hours (upregulated)",

  "ATG_AP_2_CIS_up": "Profile for target genes with AP-2 binding sites in cis-regulatory regions (upregulated)",
  "ATG_VDRE_CIS_dn": "Profile for target genes with Vitamin D Receptor Element (VDRE) binding sites in cis-regulatory regions (downregulated)",
  "ATG_VDRE_CIS_up": "Profile for target genes with Vitamin D Receptor Element (VDRE) binding sites in cis-regulatory regions (upregulated)",
  "ATG_VDR_TRANS_dn": "Profile for target genes influenced by Vitamin D Receptor (VDR) in trans-regulatory regions (downregulated)",
  "ATG_VDR_TRANS_up": "Profile for target genes influenced by Vitamin D Receptor (VDR) in trans-regulatory regions (upregulated)",

 "ATG_XTT_Cytotoxicity_up": "Profile for target genes associated with XTT cytotoxicity (upregulated)",
  "ATG_Xbp1_CIS_dn": "Profile for target genes with Xbp1 binding sites in cis-regulatory regions (downregulated)",
  "ATG_Xbp1_CIS_up": "Profile for target genes with Xbp1 binding sites in cis-regulatory regions (upregulated)",
  "ATG_p53_CIS_dn": "Profile for target genes with p53 binding sites in cis-regulatory regions (downregulated)",
  "ATG_p53_CIS_up": "Profile for target genes with p53 binding sites in cis-regulatory regions (upregulated)",
  
  "BSK_3C_Eselectin_down": "Profile for 3C cells with downregulated E-selectin expression",
  "BSK_3C_HLADR_down": "Profile for 3C cells with downregulated HLA-DR expression",
  "BSK_3C_ICAM1_down": "Profile for 3C cells with downregulated ICAM1 expression",
  "BSK_3C_IL8_down": "Profile for 3C cells with downregulated IL8 expression",
  "BSK_3C_MCP1_down": "Profile for 3C cells with downregulated MCP1 expression",
  "BSK_3C_MIG_down": "Profile for 3C cells with downregulated MIG expression",
  "BSK_3C_Proliferation_down": "Profile for 3C cells showing decreased proliferation",
  "BSK_3C_SRB_down": "Profile for 3C cells with downregulated SRB expression",
  "BSK_3C_Thrombomodulin_down": "Profile for 3C cells with downregulated Thrombomodulin expression",
  "BSK_3C_Thrombomodulin_up": "Profile for 3C cells with upregulated Thrombomodulin expression",
  "BSK_3C_TissueFactor_down": "Profile for 3C cells with downregulated Tissue Factor expression",
  "BSK_3C_TissueFactor_up": "Profile for 3C cells with upregulated Tissue Factor expression",
  "BSK_3C_VCAM1_down": "Profile for 3C cells with downregulated VCAM1 expression",
  "BSK_3C_Vis_down": "Profile for 3C cells with downregulated Vis expression",
  "BSK_3C_uPAR_down": "Profile for 3C cells with downregulated uPAR expression",

 "BSK_4H_Eotaxin3_down": "Profile for 4H cells with downregulated Eotaxin3 expression",
  "BSK_4H_MCP1_down": "Profile for 4H cells with downregulated MCP1 expression",
  "BSK_4H_Pselectin_down": "Profile for 4H cells with downregulated P-selectin expression",
  "BSK_4H_Pselectin_up": "Profile for 4H cells with upregulated P-selectin expression",
  "BSK_4H_SRB_down": "Profile for 4H cells with downregulated SRB expression",
  "BSK_4H_VCAM1_down": "Profile for 4H cells with downregulated VCAM1 expression",
  "BSK_4H_VEGFRII_down": "Profile for 4H cells with downregulated VEGFRII expression",
  "BSK_4H_uPAR_down": "Profile for 4H cells with downregulated uPAR expression",
  "BSK_4H_uPAR_up": "Profile for 4H cells with upregulated uPAR expression",

  "BSK_BE3C_HLADR_down": "Profile for BE3C cells with downregulated HLA-DR expression",
  "BSK_BE3C_IL1a_down": "Profile for BE3C cells with downregulated IL1a expression",
  "BSK_BE3C_IP10_down": "Profile for BE3C cells with downregulated IP10 expression",
  "BSK_BE3C_MIG_down": "Profile for BE3C cells with downregulated MIG expression",
  "BSK_BE3C_MMP1_down": "Profile for BE3C cells with downregulated MMP1 expression",
  "BSK_BE3C_MMP1_up": "Profile for BE3C cells with upregulated MMP1 expression",
  "BSK_BE3C_PAI1_down": "Profile for BE3C cells with downregulated PAI1 expression",
  "BSK_BE3C_SRB_down": "Profile for BE3C cells with downregulated SRB expression",
  "BSK_BE3C_TGFb1_down": "Profile for BE3C cells with downregulated TGFb1 expression",
  "BSK_BE3C_tPA_down": "Profile for BE3C cells with downregulated tPA expression",
  "BSK_BE3C_uPAR_down": "Profile for BE3C cells with downregulated uPAR expression",
  "BSK_BE3C_uPAR_up": "Profile for BE3C cells with upregulated uPAR expression",
  "BSK_BE3C_uPA_down": "Profile for BE3C cells with downregulated uPA expression",

 "BSK_CASM3C_HLADR_down": "Profile for CASM3C cells with downregulated HLA-DR expression",
  "BSK_CASM3C_IL6_down": "Profile for CASM3C cells with downregulated IL6 expression",
  "BSK_CASM3C_IL6_up": "Profile for CASM3C cells with upregulated IL6 expression",
  "BSK_CASM3C_IL8_down": "Profile for CASM3C cells with downregulated IL8 expression",
  "BSK_CASM3C_LDLR_down": "Profile for CASM3C cells with downregulated LDLR expression",
  "BSK_CASM3C_LDLR_up": "Profile for CASM3C cells with upregulated LDLR expression",
  "BSK_CASM3C_MCP1_down": "Profile for CASM3C cells with downregulated MCP1 expression",
  "BSK_CASM3C_MCP1_up": "Profile for CASM3C cells with upregulated MCP1 expression",
  "BSK_CASM3C_MCSF_down": "Profile for CASM3C cells with downregulated MCSF expression",
  "BSK_CASM3C_MCSF_up": "Profile for CASM3C cells with upregulated MCSF expression",
  "BSK_CASM3C_MIG_down": "Profile for CASM3C cells with downregulated MIG expression",
  "BSK_CASM3C_Proliferation_down": "Profile for CASM3C cells with downregulated Proliferation expression",
  "BSK_CASM3C_Proliferation_up": "Profile for CASM3C cells with upregulated Proliferation expression",
  "BSK_CASM3C_SAA_down": "Profile for CASM3C cells with downregulated SAA expression",
  "BSK_CASM3C_SAA_up": "Profile for CASM3C cells with upregulated SAA expression",
  "BSK_CASM3C_SRB_down": "Profile for CASM3C cells with downregulated SRB expression",
  "BSK_CASM3C_Thrombomodulin_down": "Profile for CASM3C cells with downregulated Thrombomodulin expression",
  "BSK_CASM3C_Thrombomodulin_up": "Profile for CASM3C cells with upregulated Thrombomodulin expression",
  "BSK_CASM3C_TissueFactor_down": "Profile for CASM3C cells with downregulated TissueFactor expression",
  "BSK_CASM3C_VCAM1_down": "Profile for CASM3C cells with downregulated VCAM1 expression",
  "BSK_CASM3C_VCAM1_up": "Profile for CASM3C cells with upregulated VCAM1 expression",
  "BSK_CASM3C_uPAR_down": "Profile for CASM3C cells with downregulated uPAR expression",
  "BSK_CASM3C_uPAR_up": "Profile for CASM3C cells with upregulated uPAR expression",


"BSK_KF3CT_ICAM1_down": "Profile for KF3CT cells with downregulated ICAM1 expression",
  "BSK_KF3CT_IL1a_down": "Profile for KF3CT cells with downregulated IL1a expression",
  "BSK_KF3CT_IP10_down": "Profile for KF3CT cells with downregulated IP10 expression",
  "BSK_KF3CT_IP10_up": "Profile for KF3CT cells with upregulated IP10 expression",
  "BSK_KF3CT_MCP1_down": "Profile for KF3CT cells with downregulated MCP1 expression",
  "BSK_KF3CT_MCP1_up": "Profile for KF3CT cells with upregulated MCP1 expression",
  "BSK_KF3CT_MMP9_down": "Profile for KF3CT cells with downregulated MMP9 expression",
  "BSK_KF3CT_SRB_down": "Profile for KF3CT cells with downregulated SRB expression",
  "BSK_KF3CT_TGFb1_down": "Profile for KF3CT cells with downregulated TGFb1 expression",
  "BSK_KF3CT_TIMP2_down": "Profile for KF3CT cells with downregulated TIMP2 expression",
  "BSK_KF3CT_uPA_down": "Profile for KF3CT cells with downregulated uPA expression",
  "BSK_LPS_CD40_down": "Profile for cells treated with LPS showing downregulated CD40 expression",
  "BSK_LPS_Eselectin_down": "Profile for cells treated with LPS showing downregulated Eselectin expression",
  "BSK_LPS_Eselectin_up": "Profile for cells treated with LPS showing upregulated Eselectin expression",
  "BSK_LPS_IL1a_down": "Profile for cells treated with LPS showing downregulated IL1a expression",
  "BSK_LPS_IL1a_up": "Profile for cells treated with LPS showing upregulated IL1a expression",
  "BSK_LPS_IL8_down": "Profile for cells treated with LPS showing downregulated IL8 expression",
  "BSK_LPS_IL8_up": "Profile for cells treated with LPS showing upregulated IL8 expression",
  "BSK_LPS_MCP1_down": "Profile for cells treated with LPS showing downregulated MCP1 expression",
  "BSK_LPS_MCSF_down": "Profile for cells treated with LPS showing downregulated MCSF expression",
  "BSK_LPS_PGE2_down": "Profile for cells treated with LPS showing downregulated PGE2 expression",
  "BSK_LPS_PGE2_up": "Profile for cells treated with LPS showing upregulated PGE2 expression",
  "BSK_LPS_SRB_down": "Profile for cells treated with LPS showing downregulated SRB expression",
  "BSK_LPS_TNFa_down": "Profile for cells treated with LPS showing downregulated TNFa expression",
  "BSK_LPS_TNFa_up": "Profile for cells treated with LPS showing upregulated TNFa expression",
  "BSK_LPS_TissueFactor_down": "Profile for cells treated with LPS showing downregulated TissueFactor expression",
  "BSK_LPS_TissueFactor_up": "Profile for cells treated with LPS showing upregulated TissueFactor expression"

      }
}
    

}

# %%
result={}

# %%
from collections import defaultdict

result=defaultdict(lambda :defaultdict(lambda :defaultdict(dict)))

# %%
for dataset in datasets:
    print(dataset)
    with open(f"{dataset}_threshold.json",'r') as f:
        task_names=settings[dataset]['output_names']
        data=json.load(f)
        
      #  result[dataset]={}

        for split in data.keys():
            for i,task in enumerate(task_names):
                print(dataset,split,task)

                result[dataset]['tasks'][task][split]= data[split][i]
# Out:
# clintox
# clintox Train FDA_APPROVED
# clintox Train CT_TOX
# clintox Val FDA_APPROVED
# clintox Val CT_TOX
# clintox Test FDA_APPROVED
# clintox Test CT_TOX
# bace
# bace Train Class
# bace Val Class
# bace Test Class
# tox21
# tox21 Train NR-AR
# tox21 Train NR-AR-LBD
# tox21 Train NR-AhR
# tox21 Train NR-Aromatase
# tox21 Train NR-ER
# tox21 Train NR-ER-LBD
# tox21 Train NR-PPAR-gamma
# tox21 Train SR-ARE
# tox21 Train SR-ATAD5
# tox21 Train SR-HSE
# tox21 Train SR-MMP
# tox21 Train SR-p53
# tox21 Val NR-AR
# tox21 Val NR-AR-LBD
# tox21 Val NR-AhR
# tox21 Val NR-Aromatase
# tox21 Val NR-ER
# tox21 Val NR-ER-LBD
# tox21 Val NR-PPAR-gamma
# tox21 Val SR-ARE
# tox21 Val SR-ATAD5
# tox21 Val SR-HSE
# tox21 Val SR-MMP
# tox21 Val SR-p53
# tox21 Test NR-AR
# tox21 Test NR-AR-LBD
# tox21 Test NR-AhR
# tox21 Test NR-Aromatase
# tox21 Test NR-ER
# tox21 Test NR-ER-LBD
# tox21 Test NR-PPAR-gamma
# tox21 Test SR-ARE
# tox21 Test SR-ATAD5
# tox21 Test SR-HSE
# tox21 Test SR-MMP
# ...

# %%
result
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'clintox': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'tasks': defaultdict(dict,
#                                       {'FDA_APPROVED': {'Train': {'roc_auc': 0.9968911711901995,
#                                          'threshold': 0.5321943179981119},
#                                         'Val': {'roc_auc': 0.9135338345864662,
#                                          'threshold': -1.2729673376073825},
#                                         'Test': {'roc_auc': 0.9738442822384428,
#                                          'threshold': -0.5037052767412789}},
#                                        'CT_TOX': {'Train': {'roc_auc': 0.9960235032190687,
#                                          'threshold': -0.49420831964777356},
#                                         'Val': {'roc_auc': 0.9332472006890611,
# ...

# %%
#append descriptions
for dataset in result.keys():
    print(dataset)
    result[dataset]['description']=descriptions[dataset]['description']
    result[dataset]['links']=descriptions[dataset]['links']
    for task in result[dataset]['tasks'].keys():
            print(task)
            result[dataset]['tasks'][task]['description']=descriptions[dataset]['tasks'][task]
# Out:
# clintox
# FDA_APPROVED
# CT_TOX
# bace
# Class
# tox21
# NR-AR
# NR-AR-LBD
# NR-AhR
# NR-Aromatase
# NR-ER
# NR-ER-LBD
# NR-PPAR-gamma
# SR-ARE
# SR-ATAD5
# SR-HSE
# SR-MMP
# SR-p53
# toxcast
# ACEA_T47D_80hr_Negative
# ACEA_T47D_80hr_Positive
# APR_HepG2_CellCycleArrest_24h_dn
# APR_HepG2_CellCycleArrest_24h_up
# APR_HepG2_CellCycleArrest_72h_dn
# APR_HepG2_CellLoss_24h_dn
# APR_HepG2_CellLoss_72h_dn
# APR_HepG2_MicrotubuleCSK_24h_dn
# APR_HepG2_MicrotubuleCSK_24h_up
# APR_HepG2_MicrotubuleCSK_72h_dn
# APR_HepG2_MicrotubuleCSK_72h_up
# APR_HepG2_MitoMass_24h_dn
# APR_HepG2_MitoMass_24h_up
# APR_HepG2_MitoMass_72h_dn
# APR_HepG2_MitoMass_72h_up
# APR_HepG2_MitoMembPot_1h_dn
# APR_HepG2_MitoMembPot_24h_dn
# APR_HepG2_MitoMembPot_72h_dn
# APR_HepG2_MitoticArrest_24h_up
# APR_HepG2_MitoticArrest_72h_up
# APR_HepG2_NuclearSize_24h_dn
# APR_HepG2_NuclearSize_72h_dn
# APR_HepG2_NuclearSize_72h_up
# APR_HepG2_OxidativeStress_24h_up
# APR_HepG2_OxidativeStress_72h_up
# ...

# %%
result['bace']
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#             {'tasks': defaultdict(dict,
#                          {'Class': {'Train': {'roc_auc': 0.9999220709099056,
#                             'threshold': 2.8799530626894594},
#                            'Val': {'roc_auc': 0.7999645641389085,
#                             'threshold': -3.7012767533998225},
#                            'Test': {'roc_auc': 0.8395083406496927,
#                             'threshold': -1.3647682220489532},
#                            'description': "Predicts whether a given molecule will inhibit the enzyme beta-secretase 1 (BACE1), which is important in Alzheimer's disease pathology."}}),
#              'description': "A dataset focused on predicting the inhibitory effects of molecules on the enzyme beta-secretase 1 (BACE1). BACE1 inhibition is a potential target for Alzheimer's disease treatment.",
#              'links': []})

# %%
with open('thresholds.json','w') as f:
    json.dump(result,f)
