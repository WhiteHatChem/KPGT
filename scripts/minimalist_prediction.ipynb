# %%
import sys
sys.path.append('.')
from src.settings import settings
#from src.utils import set_random_seed
import argparse
import torch
from torch import nn
from torch.utils.data import DataLoader
import numpy as np
import random
from src.data.featurizer import Vocab, N_ATOM_TYPES, N_BOND_TYPES
from src.data.finetune_dataset import MoleculeDataset
from src.data.collator import Collator_tune
from src.model.light import LiGhTPredictor as LiGhT
from src.trainer.finetune_trainer import Trainer
from src.trainer.evaluator import Evaluator
from src.trainer.result_tracker import Result_Tracker
from src.model_config import config_dict
from src.data.featurizer import smiles_to_graph_tune
from rdkit import Chem
#import RDKit2DNormalized
from src.data.descriptors.rdNormalizedDescriptors import RDKit2DNormalized
# Out:
# WARNING:root:No normalization for BCUT2D_MWHI
# WARNING:root:No normalization for BCUT2D_MWLOW
# WARNING:root:No normalization for BCUT2D_CHGHI
# WARNING:root:No normalization for BCUT2D_CHGLO
# WARNING:root:No normalization for BCUT2D_LOGPHI
# WARNING:root:No normalization for BCUT2D_LOGPLOW
# WARNING:root:No normalization for BCUT2D_MRHI
# WARNING:root:No normalization for BCUT2D_MRLOW

# %%
def init_params(module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=0.02)
        if module.bias is not None:
            module.bias.data.zero_()
    if isinstance(module, nn.Embedding):
        module.weight.data.normal_(mean=0.0, std=0.02)
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %%
def get_predictor(d_input_feats, n_tasks, n_layers, predictor_drop, device, d_hidden_feats=None):
    print(f'All parameters: {d_input_feats}, {n_tasks}, {n_layers}, {predictor_drop}, {device}, {d_hidden_feats}')
    if n_layers == 1:
        predictor = nn.Linear(d_input_feats, n_tasks)
    else:
        predictor = nn.ModuleList()
        predictor.append(nn.Linear(d_input_feats, d_hidden_feats))
        predictor.append(nn.Dropout(predictor_drop))
        predictor.append(nn.GELU())
        for _ in range(n_layers-2):
            predictor.append(nn.Linear(d_hidden_feats, d_hidden_feats))
            predictor.append(nn.Dropout(predictor_drop))
            predictor.append(nn.GELU())
        predictor.append(nn.Linear(d_hidden_feats, n_tasks))
        predictor = nn.Sequential(*predictor)
    predictor.apply(lambda module: init_params(module))
    return predictor.to(device)

# %%
def finetune(dataset_type,model_path):
    config = config_dict["base"]
    vocab = Vocab(N_ATOM_TYPES, N_BOND_TYPES)
    g = torch.Generator()
    g.manual_seed(42)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


    train_dataset = MoleculeDataset(root_path=args.data_path, dataset = args.dataset, dataset_type=dataset_type)
    n_tasks = len(settings[dataset_type]['output_names'])

    # Model Initialization
    model = LiGhT(
        d_node_feats=config['d_node_feats'],
        d_edge_feats=config['d_edge_feats'],
        d_g_feats=config['d_g_feats'],
        d_fp_feats=train_dataset.d_fps,
        d_md_feats=train_dataset.d_mds,
        d_hpath_ratio=config['d_hpath_ratio'],
        n_mol_layers=config['n_mol_layers'],
        path_length=config['path_length'],
        n_heads=config['n_heads'],
        n_ffn_dense_layers=config['n_ffn_dense_layers'],
        input_drop=0,
        attn_drop=0,
        feat_drop=0,
        n_node_types=vocab.vocab_size
    ).to(device)
    
    # Finetuning Setting
    model.predictor = get_predictor(d_input_feats=config['d_g_feats']*3, n_tasks=n_tasks,
                                    
                                     n_layers=2, predictor_drop=0, device=device, d_hidden_feats=256)
    model.load_state_dict({k.replace('module.',''):v for k,v in torch.load(f'{model_path}').items()})
    return model

# %%
instanciated_models={}

# %%
for model_name in settings:
    print(model_name)
    with torch.no_grad():
        instanciated_models[model_name] = finetune(model_name,
        f'/home/zach/Downloads/downstream/{model_name}/scaffold-0.pth'
        )
# Out:
# bace
# All parameters: 2304, 1, 2, 0, cpu, 256
# bbbp
# All parameters: 2304, 1, 2, 0, cpu, 256
# clintox
# All parameters: 2304, 2, 2, 0, cpu, 256
# esol
# All parameters: 2304, 1, 2, 0, cpu, 256
# freesolv
# All parameters: 2304, 1, 2, 0, cpu, 256
# lipo
# All parameters: 2304, 1, 2, 0, cpu, 256
# metstab
# All parameters: 2304, 2, 2, 0, cpu, 256
# sider
# All parameters: 2304, 27, 2, 0, cpu, 256
# tox21
# All parameters: 2304, 12, 2, 0, cpu, 256
# toxcast
# All parameters: 2304, 617, 2, 0, cpu, 256

# %%
def get_representation(smiles):
    print('constructing graphs')
    graph = smiles_to_graph_tune(smiles)
    mol = Chem.MolFromSmiles(smiles)
    ecfp= Chem.RDKFingerprint(mol, minPath=1, maxPath=7, fpSize=512)
    ecfp=torch.tensor(ecfp, dtype=torch.float32)

    generator = RDKit2DNormalized()
    md = generator.calculateMol(mol,smiles)
    md = torch.tensor(md, dtype=torch.float32)
    return graph, ecfp, md

# %%
from collections import defaultdict 
def gen_all_predictions(smiles):
    result=defaultdict(lambda :{})
    g,ecfp,md=get_representation(smiles)
    with torch.no_grad():
        for model_name in instanciated_models:
            print(model_name)
            
            predictions = instanciated_models[model_name].forward_tune(g.clone(), 
            ecfp,
             md
             )
            for prediction_name,prediction in zip(settings[model_name]['output_names'],predictions[0].tolist()):
                result[model_name][prediction_name]={
                    "value":prediction,
                   
                    "type":settings[model_name]['output_types'][prediction_name]
                }
                if "regression"==settings[model_name]['output_types'][prediction_name]:
                    result[model_name][prediction_name]["units"]=settings[model_name]['units']

                
    return dict(result)

# %%
gen_all_predictions("CCN(CC)C(=O)[C@H]1CN([C@@H]2CC3=CNC4=CC=CC(=C34)C2=C1)C")
# Out:
# constructing graphs
# bace
# bbbp
# clintox
# esol
# freesolv
# lipo
# metstab
# sider
# tox21
# toxcast
# {'bace': {'Class': -2.109135866165161},
#  'bbbp': {'p_np': 9.484339714050293},
#  'clintox': {'FDA_APPROVED': -4.3052978515625, 'CT_TOX': 3.5269336700439453},
#  'esol': {'logSolubility': -1.4553965330123901},
#  'freesolv': {'freesolv': -2.0622310638427734},
#  'lipo': {'lipo': 0.41645899415016174},
#  'metstab': {'high': -2.5849862098693848, 'low': 1.8073099851608276},
#  'sider': {'Hepatobiliary disorders': -1.2984468936920166,
#   'Metabolism and nutrition disorders': 0.3069888949394226,
#   'Product issues': -3.098461627960205,
#   'Eye disorders': 0.08531132340431213,
#   'Investigations': 0.8364753127098083,
#   'Musculoskeletal and connective tissue disorders': 1.5021477937698364,
#   'Gastrointestinal disorders': 2.887082576751709,
#   'Social circumstances': -1.3231562376022339,
#   'Immune system disorders': -0.8708500266075134,
#   'Reproductive system and breast disorders': -0.2558687627315521,
#   'Neoplasms benign, malignant and unspecified (incl cysts and polyps)': -1.4556807279586792,
#   'General disorders and administration site conditions': 1.6626168489456177,
#   'Endocrine disorders': -1.4864848852157593,
#   'Surgical and medical procedures': -1.77353036403656,
#   'Vascular disorders': 1.5863795280456543,
#   'Blood and lymphatic system disorders': -0.6156831979751587,
#   'Skin and subcutaneous tissue disorders': 2.177199125289917,
#   'Congenital, familial and genetic disorders': -2.6576967239379883,
#   'Infections and infestations': 0.17701715230941772,
#   'Respiratory, thoracic and mediastinal disorders': 0.5490899682044983,
#   'Psychiatric disorders': 1.4949016571044922,
#   'Renal and urinary disorders': -0.3847501277923584,
#   'Pregnancy, puerperium and perinatal conditions': -2.309048652648926,
#   'Ear and labyrinth disorders': -0.1822686642408371,
#   'Cardiac disorders': 0.5669922232627869,
#   'Nervous system disorders': 2.7733917236328125,
#   'Injury, poisoning and procedural complications': 0.2866986095905304},
#  'tox21': {'NR-AR': -4.147104740142822,
#   'NR-AR-LBD': -4.129909515380859,
#   'NR-AhR': 0.12164841592311859,
#   'NR-Aromatase': -1.9504733085632324,
#   'NR-ER': -2.662341356277466,
#   'NR-ER-LBD': -3.617144823074341,
#   'NR-PPAR-gamma': -4.244645118713379,
#   'SR-ARE': -1.0229066610336304,
#   'SR-ATAD5': -3.6280767917633057,
#   'SR-HSE': -2.4582934379577637,
#   'SR-MMP': -0.8028607964515686,
#   'SR-p53': -1.9854702949523926},
#  'toxcast': {'ACEA_T47D_80hr_Negative': -2.6011829376220703,
#   'ACEA_T47D_80hr_Positive': -2.0562448501586914,
#   'APR_HepG2_CellCycleArrest_24h_dn': -3.0460691452026367,
#   'APR_HepG2_CellCycleArrest_24h_up': -3.266481637954712,
#   'APR_HepG2_CellCycleArrest_72h_dn': -1.9335544109344482,
#   'APR_HepG2_CellLoss_24h_dn': -2.1627197265625,
#   'APR_HepG2_CellLoss_72h_dn': -0.746343731880188,
#   'APR_HepG2_MicrotubuleCSK_24h_dn': -5.453461647033691,
#   'APR_HepG2_MicrotubuleCSK_24h_up': -3.185953140258789,
#   'APR_HepG2_MicrotubuleCSK_72h_dn': -3.4889261722564697,
#   'APR_HepG2_MicrotubuleCSK_72h_up': -2.751897096633911,
#   'APR_HepG2_MitoMass_24h_dn': -2.6106388568878174,
#   'APR_HepG2_MitoMass_24h_up': -6.3493194580078125,
#   'APR_HepG2_MitoMass_72h_dn': -1.9215577840805054,
#   'APR_HepG2_MitoMass_72h_up': -2.6853506565093994,
#   'APR_HepG2_MitoMembPot_1h_dn': -5.076374530792236,
#   'APR_HepG2_MitoMembPot_24h_dn': -3.72225022315979,
#   'APR_HepG2_MitoMembPot_72h_dn': -3.0559661388397217,
#   'APR_HepG2_MitoticArrest_24h_up': -2.4410336017608643,
#   'APR_HepG2_MitoticArrest_72h_up': -0.7268378734588623,
#   'APR_HepG2_NuclearSize_24h_dn': -4.968463897705078,
#   'APR_HepG2_NuclearSize_72h_dn': -4.5940260887146,
#   'APR_HepG2_NuclearSize_72h_up': -4.698360443115234,
#   'APR_HepG2_OxidativeStress_24h_up': -2.349299907684326,
#   'APR_HepG2_OxidativeStress_72h_up': -1.1620515584945679,
#   'APR_HepG2_StressKinase_1h_up': -6.462027072906494,
#   'APR_HepG2_StressKinase_24h_up': -3.9623353481292725,
#   'APR_HepG2_StressKinase_72h_up': -3.2466111183166504,
#   'APR_HepG2_p53Act_24h_up': -3.120577335357666,
#   'APR_HepG2_p53Act_72h_up': -1.0955740213394165,
#   'APR_Hepat_Apoptosis_24hr_up': -3.5520966053009033,
#   'APR_Hepat_Apoptosis_48hr_up': -2.920877695083618,
#   'APR_Hepat_CellLoss_24hr_dn': -3.0862884521484375,
#   'APR_Hepat_CellLoss_48hr_dn': -1.813696265220642,
#   'APR_Hepat_DNADamage_24hr_up': -2.0118954181671143,
#   'APR_Hepat_DNADamage_48hr_up': -1.5702037811279297,
#   'APR_Hepat_DNATexture_24hr_up': -3.049508571624756,
#   'APR_Hepat_DNATexture_48hr_up': -3.1828720569610596,
#   'APR_Hepat_MitoFxnI_1hr_dn': -2.3841261863708496,
#   'APR_Hepat_MitoFxnI_24hr_dn': -1.6986039876937866,
#   'APR_Hepat_MitoFxnI_48hr_dn': -2.4603030681610107,
#   'APR_Hepat_NuclearSize_24hr_dn': -5.2653350830078125,
#   'APR_Hepat_NuclearSize_48hr_dn': -3.8378944396972656,
#   'APR_Hepat_Steatosis_24hr_up': -4.692750930786133,
#   'APR_Hepat_Steatosis_48hr_up': -4.046502590179443,
#   'ATG_AP_1_CIS_dn': -5.364798069000244,
#   'ATG_AP_1_CIS_up': -1.6821602582931519,
#   'ATG_AP_2_CIS_dn': -3.1217644214630127,
#   'ATG_AP_2_CIS_up': -7.83932638168335,
#   'ATG_AR_TRANS_dn': -6.820450305938721,
#   'ATG_AR_TRANS_up': -6.779083251953125,
#   'ATG_Ahr_CIS_dn': -3.7609221935272217,
#   'ATG_Ahr_CIS_up': -1.4875730276107788,
#   'ATG_BRE_CIS_dn': -4.482372283935547,
#   'ATG_BRE_CIS_up': -2.8542063236236572,
#   'ATG_CAR_TRANS_dn': -6.346540927886963,
#   'ATG_CAR_TRANS_up': -6.053339958190918,
#   'ATG_CMV_CIS_dn': -5.78951358795166,
#   'ATG_CMV_CIS_up': -0.7680351734161377,
#   'ATG_CRE_CIS_dn': -6.635200023651123,
#   'ATG_CRE_CIS_up': -0.988086462020874,
#   'ATG_C_EBP_CIS_dn': -5.675195217132568,
#   'ATG_C_EBP_CIS_up': -2.392754316329956,
#   'ATG_DR4_LXR_CIS_dn': -2.1138975620269775,
#   'ATG_DR4_LXR_CIS_up': -4.131519794464111,
#   'ATG_DR5_CIS_dn': -5.434966087341309,
#   'ATG_DR5_CIS_up': -1.888594388961792,
#   'ATG_E2F_CIS_dn': -3.588512897491455,
#   'ATG_E2F_CIS_up': -7.851698398590088,
#   'ATG_EGR_CIS_up': -1.560027003288269,
#   'ATG_ERE_CIS_dn': -3.0427143573760986,
#   'ATG_ERE_CIS_up': -0.8937761783599854,
#   'ATG_ERRa_TRANS_dn': -6.360945224761963,
#   'ATG_ERRg_TRANS_dn': -7.216695785522461,
#   'ATG_ERRg_TRANS_up': -7.713592052459717,
#   'ATG_ERa_TRANS_up': -1.7323485612869263,
#   'ATG_E_Box_CIS_dn': -1.2850968837738037,
#   'ATG_E_Box_CIS_up': -5.011590480804443,
#   'ATG_Ets_CIS_dn': -3.4573001861572266,
#   'ATG_Ets_CIS_up': -9.003110885620117,
#   'ATG_FXR_TRANS_up': -5.062915325164795,
#   'ATG_FoxA2_CIS_dn': -6.793760299682617,
#   'ATG_FoxA2_CIS_up': -4.418435573577881,
#   'ATG_FoxO_CIS_dn': -3.4404258728027344,
#   'ATG_FoxO_CIS_up': -6.357396602630615,
#   'ATG_GAL4_TRANS_dn': -5.389563083648682,
#   'ATG_GATA_CIS_dn': -4.885768413543701,
#   'ATG_GATA_CIS_up': -4.907094955444336,
#   'ATG_GLI_CIS_dn': -5.085101127624512,
#   'ATG_GLI_CIS_up': -5.431941032409668,
#   'ATG_GRE_CIS_dn': -3.776944637298584,
#   'ATG_GRE_CIS_up': -4.124703884124756,
#   'ATG_GR_TRANS_dn': -6.10850715637207,
#   'ATG_GR_TRANS_up': -5.884493350982666,
#   'ATG_HIF1a_CIS_dn': -2.9667181968688965,
#   'ATG_HIF1a_CIS_up': -2.5445077419281006,
#   'ATG_HNF4a_TRANS_dn': -4.814351558685303,
#   'ATG_HNF4a_TRANS_up': -6.963896751403809,
#   'ATG_HNF6_CIS_dn': -5.444733142852783,
#   'ATG_HNF6_CIS_up': -5.840803146362305,
#   'ATG_HSE_CIS_dn': -4.764589309692383,
#   'ATG_HSE_CIS_up': -3.4911253452301025,
#   'ATG_IR1_CIS_dn': -3.399277925491333,
#   'ATG_IR1_CIS_up': -4.570122718811035,
#   'ATG_ISRE_CIS_dn': -1.4132051467895508,
#   'ATG_ISRE_CIS_up': -6.573235034942627,
#   'ATG_LXRa_TRANS_dn': -4.6303887367248535,
#   'ATG_LXRa_TRANS_up': -4.166218280792236,
#   'ATG_LXRb_TRANS_dn': -6.6952056884765625,
#   'ATG_LXRb_TRANS_up': -3.7735629081726074,
#   'ATG_MRE_CIS_up': -0.8870083689689636,
#   'ATG_M_06_TRANS_up': -6.303063869476318,
#   'ATG_M_19_CIS_dn': -4.352674961090088,
#   'ATG_M_19_TRANS_dn': -6.637659549713135,
#   'ATG_M_19_TRANS_up': -5.389303207397461,
#   'ATG_M_32_CIS_dn': -5.93295955657959,
#   'ATG_M_32_CIS_up': -5.857625484466553,
#   'ATG_M_32_TRANS_dn': -5.4325385093688965,
#   'ATG_M_32_TRANS_up': -6.0433244705200195,
#   'ATG_M_61_TRANS_up': -6.325841903686523,
#   'ATG_Myb_CIS_dn': -5.527854919433594,
#   'ATG_Myb_CIS_up': -5.065634250640869,
#   'ATG_Myc_CIS_dn': -6.3649001121521,
#   'ATG_Myc_CIS_up': -3.8938629627227783,
#   'ATG_NFI_CIS_dn': -4.647395610809326,
#   'ATG_NFI_CIS_up': -3.1290013790130615,
#   'ATG_NF_kB_CIS_dn': -2.8406307697296143,
#   'ATG_NF_kB_CIS_up': -3.9343059062957764,
#   'ATG_NRF1_CIS_dn': -2.2254388332366943,
#   'ATG_NRF1_CIS_up': -6.0311198234558105,
#   'ATG_NRF2_ARE_CIS_dn': -6.617397785186768,
#   'ATG_NRF2_ARE_CIS_up': 0.2724587619304657,
#   'ATG_NURR1_TRANS_dn': -7.09738826751709,
#   'ATG_NURR1_TRANS_up': -3.3080554008483887,
#   'ATG_Oct_MLP_CIS_dn': -7.190680503845215,
#   'ATG_Oct_MLP_CIS_up': -1.1631251573562622,
#   'ATG_PBREM_CIS_dn': -8.301487922668457,
#   'ATG_PBREM_CIS_up': -1.9309701919555664,
#   'ATG_PPARa_TRANS_dn': -7.214469909667969,
#   'ATG_PPARa_TRANS_up': -4.922848224639893,
#   'ATG_PPARd_TRANS_up': -5.217381954193115,
#   'ATG_PPARg_TRANS_up': -1.5761123895645142,
#   'ATG_PPRE_CIS_dn': -4.494858264923096,
#   'ATG_PPRE_CIS_up': -2.3001620769500732,
#   'ATG_PXRE_CIS_dn': -3.691577196121216,
#   'ATG_PXRE_CIS_up': 1.1733466386795044,
#   'ATG_PXR_TRANS_dn': -6.856714248657227,
#   'ATG_PXR_TRANS_up': -0.17271657288074493,
#   'ATG_Pax6_CIS_up': -2.0947391986846924,
#   'ATG_RARa_TRANS_dn': -3.175241470336914,
#   'ATG_RARa_TRANS_up': -5.387369632720947,
#   'ATG_RARb_TRANS_dn': -3.9999194145202637,
#   'ATG_RARb_TRANS_up': -5.096587181091309,
#   'ATG_RARg_TRANS_dn': -5.938313007354736,
#   'ATG_RARg_TRANS_up': -6.054060459136963,
#   'ATG_RORE_CIS_dn': -6.523705005645752,
#   'ATG_RORE_CIS_up': -1.368512511253357,
#   'ATG_RORb_TRANS_dn': -6.195168972015381,
#   'ATG_RORg_TRANS_dn': -6.498629093170166,
#   'ATG_RORg_TRANS_up': -8.273143768310547,
#   'ATG_RXRa_TRANS_dn': -5.837749004364014,
#   'ATG_RXRa_TRANS_up': -5.234704494476318,
#   'ATG_RXRb_TRANS_dn': -4.325336456298828,
#   'ATG_RXRb_TRANS_up': -3.323565721511841,
#   'ATG_SREBP_CIS_dn': -6.357790470123291,
#   'ATG_SREBP_CIS_up': -1.3159246444702148,
#   'ATG_STAT3_CIS_dn': -4.6422553062438965,
#   'ATG_STAT3_CIS_up': -4.764222621917725,
#   'ATG_Sox_CIS_dn': -6.966208457946777,
#   'ATG_Sox_CIS_up': -2.8417184352874756,
#   'ATG_Sp1_CIS_dn': -6.095108985900879,
#   'ATG_Sp1_CIS_up': -2.4488883018493652,
#   'ATG_TAL_CIS_dn': -5.439522743225098,
#   'ATG_TAL_CIS_up': -3.5237419605255127,
#   'ATG_TA_CIS_dn': -7.224476337432861,
#   'ATG_TA_CIS_up': -3.66748046875,
#   'ATG_TCF_b_cat_CIS_dn': -0.11942833662033081,
#   'ATG_TCF_b_cat_CIS_up': -6.542105674743652,
#   'ATG_TGFb_CIS_dn': -4.571488380432129,
#   'ATG_TGFb_CIS_up': -4.217700958251953,
#   'ATG_THRa1_TRANS_dn': -4.255317211151123,
#   'ATG_THRa1_TRANS_up': -3.365100383758545,
#   'ATG_VDRE_CIS_dn': -7.809116840362549,
#   'ATG_VDRE_CIS_up': 0.40061435103416443,
#   'ATG_VDR_TRANS_dn': -5.78762674331665,
#   'ATG_VDR_TRANS_up': -5.405300617218018,
#   'ATG_XTT_Cytotoxicity_up': -3.7102622985839844,
#   'ATG_Xbp1_CIS_dn': -6.573897838592529,
#   'ATG_Xbp1_CIS_up': -2.591399908065796,
#   'ATG_p53_CIS_dn': -2.1184356212615967,
#   'ATG_p53_CIS_up': -5.457548141479492,
#   'BSK_3C_Eselectin_down': -3.251171827316284,
#   'BSK_3C_HLADR_down': -1.480054259300232,
#   'BSK_3C_ICAM1_down': -7.214817523956299,
#   'BSK_3C_IL8_down': -3.7563023567199707,
#   'BSK_3C_MCP1_down': -2.7145934104919434,
#   'BSK_3C_MIG_down': -8.14315128326416,
#   'BSK_3C_Proliferation_down': -2.1168885231018066,
#   'BSK_3C_SRB_down': -2.2462751865386963,
#   'BSK_3C_Thrombomodulin_down': -4.7624897956848145,
#   'BSK_3C_Thrombomodulin_up': -4.6120991706848145,
#   'BSK_3C_TissueFactor_down': -4.43791389465332,
#   'BSK_3C_TissueFactor_up': -3.2839906215667725,
#   'BSK_3C_VCAM1_down': -4.544008255004883,
#   'BSK_3C_Vis_down': -1.6771658658981323,
#   'BSK_3C_uPAR_down': -2.6045188903808594,
#   'BSK_4H_Eotaxin3_down': -2.502206563949585,
#   'BSK_4H_MCP1_down': -3.4102203845977783,
#   'BSK_4H_Pselectin_down': -4.025208950042725,
#   'BSK_4H_Pselectin_up': -3.0173423290252686,
#   'BSK_4H_SRB_down': -3.046098232269287,
#   'BSK_4H_VCAM1_down': -2.093224048614502,
#   'BSK_4H_VEGFRII_down': -5.138293266296387,
#   'BSK_4H_uPAR_down': -2.8838982582092285,
#   'BSK_4H_uPAR_up': -6.003896236419678,
#   'BSK_BE3C_HLADR_down': -3.137394666671753,
#   'BSK_BE3C_IL1a_down': -5.446091651916504,
#   'BSK_BE3C_IP10_down': -3.370389938354492,
#   'BSK_BE3C_MIG_down': -7.0786004066467285,
#   'BSK_BE3C_MMP1_down': -4.4574875831604,
#   'BSK_BE3C_MMP1_up': -4.365958213806152,
#   'BSK_BE3C_PAI1_down': -2.7575831413269043,
#   'BSK_BE3C_SRB_down': -5.683246612548828,
#   'BSK_BE3C_TGFb1_down': -4.566766738891602,
#   'BSK_BE3C_tPA_down': -4.899717807769775,
#   'BSK_BE3C_uPAR_down': -6.042262554168701,
#   'BSK_BE3C_uPAR_up': -4.71652889251709,
#   'BSK_BE3C_uPA_down': -4.2738213539123535,
#   'BSK_CASM3C_HLADR_down': -3.8306868076324463,
#   'BSK_CASM3C_IL6_down': -5.141824722290039,
#   'BSK_CASM3C_IL6_up': -3.5905749797821045,
#   'BSK_CASM3C_IL8_down': -5.974963188171387,
#   'BSK_CASM3C_LDLR_down': -4.419966697692871,
#   'BSK_CASM3C_LDLR_up': -2.9884727001190186,
#   'BSK_CASM3C_MCP1_down': -4.809511661529541,
#   'BSK_CASM3C_MCP1_up': -4.231861591339111,
#   'BSK_CASM3C_MCSF_down': -3.849867582321167,
#   'BSK_CASM3C_MCSF_up': -6.749120712280273,
#   'BSK_CASM3C_MIG_down': -5.4030351638793945,
#   'BSK_CASM3C_Proliferation_down': -2.441582441329956,
#   'BSK_CASM3C_Proliferation_up': -4.93007230758667,
#   'BSK_CASM3C_SAA_down': -5.610188961029053,
#   'BSK_CASM3C_SAA_up': -6.751824378967285,
#   'BSK_CASM3C_SRB_down': -6.053483963012695,
#   'BSK_CASM3C_Thrombomodulin_down': -6.9925384521484375,
#   'BSK_CASM3C_Thrombomodulin_up': -4.09662389755249,
#   'BSK_CASM3C_TissueFactor_down': -4.456594467163086,
#   'BSK_CASM3C_VCAM1_down': -5.3663482666015625,
#   'BSK_CASM3C_VCAM1_up': -3.911203384399414,
#   'BSK_CASM3C_uPAR_down': -4.727510929107666,
#   'BSK_CASM3C_uPAR_up': -5.845941543579102,
#   'BSK_KF3CT_ICAM1_down': -5.9912543296813965,
#   'BSK_KF3CT_IL1a_down': -4.864480495452881,
#   'BSK_KF3CT_IP10_down': -3.790849208831787,
#   'BSK_KF3CT_IP10_up': -5.0131144523620605,
#   'BSK_KF3CT_MCP1_down': -5.052759647369385,
#   'BSK_KF3CT_MCP1_up': -4.587436199188232,
#   'BSK_KF3CT_MMP9_down': -3.2184090614318848,
#   'BSK_KF3CT_SRB_down': -7.130544185638428,
#   'BSK_KF3CT_TGFb1_down': -4.298703670501709,
#   'BSK_KF3CT_TIMP2_down': -5.0808210372924805,
#   'BSK_KF3CT_uPA_down': -4.634932994842529,
#   'BSK_LPS_CD40_down': -3.191040277481079,
#   'BSK_LPS_Eselectin_down': -3.666417360305786,
#   'BSK_LPS_Eselectin_up': -4.879450798034668,
#   'BSK_LPS_IL1a_down': -4.223312854766846,
#   'BSK_LPS_IL1a_up': -5.639397144317627,
#   'BSK_LPS_IL8_down': -3.758671760559082,
#   'BSK_LPS_IL8_up': -4.262564182281494,
#   'BSK_LPS_MCP1_down': -3.4027345180511475,
#   'BSK_LPS_MCSF_down': -2.8161871433258057,
#   'BSK_LPS_PGE2_down': -1.9105585813522339,
#   'BSK_LPS_PGE2_up': -3.388014078140259,
#   'BSK_LPS_SRB_down': -3.607456922531128,
#   'BSK_LPS_TNFa_down': -2.737506866455078,
#   'BSK_LPS_TNFa_up': -3.940612554550171,
#   'BSK_LPS_TissueFactor_down': -3.8057005405426025,
#   'BSK_LPS_TissueFactor_up': -3.5536930561065674,
#   'BSK_LPS_VCAM1_down': -2.1747632026672363,
#   'BSK_SAg_CD38_down': -2.8829009532928467,
#   'BSK_SAg_CD40_down': -2.7826993465423584,
#   'BSK_SAg_CD69_down': -3.3596889972686768,
#   'BSK_SAg_Eselectin_down': -2.9202845096588135,
#   'BSK_SAg_Eselectin_up': -3.693469524383545,
#   'BSK_SAg_IL8_down': -3.6417648792266846,
#   'BSK_SAg_IL8_up': -4.403202533721924,
#   'BSK_SAg_MCP1_down': -3.7879066467285156,
#   'BSK_SAg_MIG_down': -6.198936939239502,
#   'BSK_SAg_PBMCCytotoxicity_down': -3.8533475399017334,
#   'BSK_SAg_PBMCCytotoxicity_up': -3.662949323654175,
#   'BSK_SAg_Proliferation_down': -1.7349061965942383,
#   'BSK_SAg_SRB_down': -2.5256423950195312,
#   'BSK_hDFCGF_CollagenIII_down': -3.3480172157287598,
#   'BSK_hDFCGF_EGFR_down': -5.619298934936523,
#   'BSK_hDFCGF_EGFR_up': -5.039487361907959,
#   'BSK_hDFCGF_IL8_down': -6.689805507659912,
#   'BSK_hDFCGF_IP10_down': -2.918718099594116,
#   'BSK_hDFCGF_MCSF_down': -3.530463218688965,
#   'BSK_hDFCGF_MIG_down': -5.338809013366699,
#   'BSK_hDFCGF_MMP1_down': -4.408276557922363,
#   'BSK_hDFCGF_MMP1_up': -3.1695122718811035,
#   'BSK_hDFCGF_PAI1_down': -3.8019659519195557,
#   'BSK_hDFCGF_Proliferation_down': -0.8239229917526245,
#   'BSK_hDFCGF_SRB_down': -4.7285261154174805,
#   'BSK_hDFCGF_TIMP1_down': -5.174011707305908,
#   'BSK_hDFCGF_VCAM1_down': -2.8083090782165527,
#   'CEETOX_H295R_11DCORT_dn': 0.5278024077415466,
#   'CEETOX_H295R_ANDR_dn': 0.0995837152004242,
#   'CEETOX_H295R_CORTISOL_dn': 0.0637982040643692,
#   'CEETOX_H295R_DOC_dn': -1.0389883518218994,
#   'CEETOX_H295R_DOC_up': -3.258456230163574,
#   'CEETOX_H295R_ESTRADIOL_dn': -4.016709327697754,
#   'CEETOX_H295R_ESTRADIOL_up': -3.094040870666504,
#   'CEETOX_H295R_ESTRONE_dn': -3.471167802810669,
#   'CEETOX_H295R_ESTRONE_up': -2.62556529045105,
#   'CEETOX_H295R_OHPREG_up': -3.4790782928466797,
#   'CEETOX_H295R_OHPROG_dn': -1.1164745092391968,
#   'CEETOX_H295R_OHPROG_up': -2.037160873413086,
#   'CEETOX_H295R_PROG_up': -2.375370502471924,
#   'CEETOX_H295R_TESTO_dn': -0.012837542220950127,
#   'CLD_ABCB1_48hr': -4.495931148529053,
#   'CLD_ABCG2_48hr': -2.527177572250366,
#   'CLD_CYP1A1_24hr': -2.263284206390381,
#   'CLD_CYP1A1_48hr': -1.9558502435684204,
#   'CLD_CYP1A1_6hr': -1.4127662181854248,
#   'CLD_CYP1A2_24hr': -2.392855644226074,
#   'CLD_CYP1A2_48hr': -1.6550624370574951,
#   'CLD_CYP1A2_6hr': -2.271458387374878,
#   'CLD_CYP2B6_24hr': 0.48139676451683044,
#   'CLD_CYP2B6_48hr': -0.9518213868141174,
#   'CLD_CYP2B6_6hr': 0.43886348605155945,
#   'CLD_CYP3A4_24hr': -1.0080171823501587,
#   'CLD_CYP3A4_48hr': 0.1166708841919899,
#   'CLD_CYP3A4_6hr': -2.295837163925171,
#   'CLD_GSTA2_48hr': -3.352492094039917,
#   'CLD_SULT2A_24hr': -0.9416790008544922,
#   'CLD_SULT2A_48hr': -0.21537168323993683,
#   'CLD_UGT1A1_24hr': -3.3289270401000977,
#   'CLD_UGT1A1_48hr': -2.4136974811553955,
#   'NCCT_HEK293T_CellTiterGLO': 0.9597592949867249,
#   'NCCT_QuantiLum_inhib_2_dn': -1.362868309020996,
#   'NCCT_QuantiLum_inhib_dn': 0.40608319640159607,
#   'NCCT_TPO_AUR_dn': 1.9988765716552734,
#   'NCCT_TPO_GUA_dn': 0.5062646865844727,
#   'NHEERL_ZF_144hpf_TERATOSCORE_up': -0.35232633352279663,
#   'NVS_ADME_hCYP19A1': -2.5808827877044678,
#   'NVS_ADME_hCYP1A1': -0.7123937606811523,
#   'NVS_ADME_hCYP1A2': 0.8243179321289062,
#   'NVS_ADME_hCYP2A6': -1.8299847841262817,
#   'NVS_ADME_hCYP2B6': 1.6520309448242188,
#   'NVS_ADME_hCYP2C19': 1.798893928527832,
#   'NVS_ADME_hCYP2C9': 3.6394665241241455,
#   'NVS_ADME_hCYP2D6': 1.8969388008117676,
#   'NVS_ADME_hCYP3A4': -2.020498037338257,
#   'NVS_ADME_hCYP4F12': -1.36279296875,
#   'NVS_ADME_rCYP2C12': -1.091878056526184,
#   'NVS_ENZ_hAChE': 1.1511033773422241,
#   'NVS_ENZ_hAMPKa1': -2.6316516399383545,
#   'NVS_ENZ_hAurA': -0.8939881920814514,
#   'NVS_ENZ_hBACE': -0.28448083996772766,
#   'NVS_ENZ_hCASP5': -0.5948328971862793,
#   'NVS_ENZ_hCK1D': -0.39983049035072327,
#   'NVS_ENZ_hDUSP3': 1.4502404928207397,
#   'NVS_ENZ_hES': 0.5647504329681396,
#   'NVS_ENZ_hElastase': -1.220818281173706,
#   'NVS_ENZ_hFGFR1': -2.0209410190582275,
#   'NVS_ENZ_hGSK3b': -1.2784843444824219,
#   'NVS_ENZ_hMMP1': -0.6905859112739563,
#   'NVS_ENZ_hMMP13': 0.22166180610656738,
#   'NVS_ENZ_hMMP2': -0.7789832949638367,
#   'NVS_ENZ_hMMP3': -0.32140636444091797,
#   'NVS_ENZ_hMMP7': -1.2549821138381958,
#   'NVS_ENZ_hMMP9': 0.6980021595954895,
#   'NVS_ENZ_hPDE10': -1.2879681587219238,
#   'NVS_ENZ_hPDE4A1': -0.6404975652694702,
#   'NVS_ENZ_hPDE5': 0.012277628295123577,
#   'NVS_ENZ_hPI3Ka': -4.599126815795898,
#   'NVS_ENZ_hPTEN': -2.592191696166992,
#   'NVS_ENZ_hPTPN11': -3.0794777870178223,
#   'NVS_ENZ_hPTPN12': -1.1171574592590332,
#   'NVS_ENZ_hPTPN13': -0.5116653442382812,
#   'NVS_ENZ_hPTPN9': 0.006078691687434912,
#   'NVS_ENZ_hPTPRC': -0.44159629940986633,
#   'NVS_ENZ_hSIRT1': -3.526870012283325,
#   'NVS_ENZ_hSIRT2': -1.8348333835601807,
#   'NVS_ENZ_hTrkA': -0.16735734045505524,
#   'NVS_ENZ_hVEGFR2': -1.6131294965744019,
#   'NVS_ENZ_oCOX1': 0.7437364459037781,
#   'NVS_ENZ_oCOX2': 0.829368531703949,
#   'NVS_ENZ_rAChE': 1.7041337490081787,
#   'NVS_ENZ_rCNOS': 0.8727931976318359,
#   'NVS_ENZ_rMAOAC': 0.7279499769210815,
#   'NVS_ENZ_rMAOAP': -1.8216471672058105,
#   'NVS_ENZ_rMAOBC': 0.597089946269989,
#   'NVS_ENZ_rMAOBP': 0.16684594750404358,
#   'NVS_ENZ_rabI2C': 0.51416015625,
#   'NVS_GPCR_bAdoR_NonSelective': -0.3203263580799103,
#   'NVS_GPCR_bDR_NonSelective': -0.3778481185436249,
#   'NVS_GPCR_g5HT4': 0.7243263125419617,
#   'NVS_GPCR_gH2': 1.149521827697754,
#   'NVS_GPCR_gLTB4': 0.6841080188751221,
#   'NVS_GPCR_gLTD4': -1.623077392578125,
#   'NVS_GPCR_gMPeripheral_NonSelective': -1.0243167877197266,
#   'NVS_GPCR_gOpiateK': 1.1249021291732788,
#   'NVS_GPCR_h5HT2A': 0.5775880813598633,
#   'NVS_GPCR_h5HT5A': -0.5336343050003052,
#   'NVS_GPCR_h5HT6': 0.3702462315559387,
#   'NVS_GPCR_h5HT7': 3.3275721073150635,
#   'NVS_GPCR_hAT1': -2.5200536251068115,
#   'NVS_GPCR_hAdoRA1': 0.8077749013900757,
#   'NVS_GPCR_hAdoRA2a': 1.7701178789138794,
#   'NVS_GPCR_hAdra2A': 1.3841501474380493,
#   'NVS_GPCR_hAdra2C': 1.9194490909576416,
#   'NVS_GPCR_hAdrb1': 0.23898056149482727,
#   'NVS_GPCR_hAdrb2': -1.266098976135254,
#   'NVS_GPCR_hAdrb3': -2.3627917766571045,
#   'NVS_GPCR_hDRD1': 0.2978138327598572,
#   'NVS_GPCR_hDRD2s': 0.3842465877532959,
#   'NVS_GPCR_hDRD4.4': 1.8577982187271118,
#   'NVS_GPCR_hH1': -0.6262763738632202,
#   'NVS_GPCR_hLTB4_BLT1': -1.3302556276321411,
#   'NVS_GPCR_hM1': -0.2576822340488434,
#   'NVS_GPCR_hM2': 0.5893876552581787,
#   'NVS_GPCR_hM3': 0.30749064683914185,
#   'NVS_GPCR_hM4': 0.21236415207386017,
#   'NVS_GPCR_hNK2': -1.518168568611145,
#   'NVS_GPCR_hOpiate_D1': -2.5452048778533936,
#   'NVS_GPCR_hOpiate_mu': -1.7771433591842651,
#   'NVS_GPCR_hTXA2': -0.28556206822395325,
#   'NVS_GPCR_p5HT2C': 0.5313616991043091,
#   'NVS_GPCR_r5HT1_NonSelective': -0.5922570824623108,
#   'NVS_GPCR_r5HT_NonSelective': -0.6615179181098938,
#   'NVS_GPCR_rAdra1B': 0.7238520383834839,
#   'NVS_GPCR_rAdra1_NonSelective': 0.09140167385339737,
#   'NVS_GPCR_rAdra2_NonSelective': 0.7246037125587463,
#   'NVS_GPCR_rAdrb_NonSelective': 0.13734763860702515,
#   'NVS_GPCR_rNK1': -0.9839534163475037,
#   'NVS_GPCR_rNK3': -2.4379239082336426,
#   'NVS_GPCR_rOpiate_NonSelective': 0.9508072733879089,
#   'NVS_GPCR_rOpiate_NonSelectiveNa': 0.39128944277763367,
#   'NVS_GPCR_rSST': 0.8774560689926147,
#   'NVS_GPCR_rTRH': -4.8741254806518555,
#   'NVS_GPCR_rV1': -0.6975247263908386,
#   'NVS_GPCR_rabPAF': 0.0643278956413269,
#   'NVS_GPCR_rmAdra2B': 2.5945022106170654,
#   'NVS_IC_hKhERGCh': -1.7187401056289673,
#   'NVS_IC_rCaBTZCHL': 1.2104055881500244,
#   'NVS_IC_rCaDHPRCh_L': -0.8882846236228943,
#   'NVS_IC_rNaCh_site2': 3.025226593017578,
#   'NVS_LGIC_bGABARa1': 0.27727651596069336,
#   'NVS_LGIC_h5HT3': -2.1759181022644043,
#   'NVS_LGIC_hNNR_NBungSens': 0.891749382019043,
#   'NVS_LGIC_rGABAR_NonSelective': -1.6657048463821411,
#   'NVS_LGIC_rNNR_BungSens': 1.261201024055481,
#   'NVS_MP_hPBR': 1.4588220119476318,
#   'NVS_MP_rPBR': -0.07698918879032135,
#   'NVS_NR_bER': -4.424401760101318,
#   'NVS_NR_bPR': -1.1623927354812622,
#   'NVS_NR_cAR': 0.7620863914489746,
#   'NVS_NR_hAR': -1.1417717933654785,
#   'NVS_NR_hCAR_Antagonist': -0.45834386348724365,
#   'NVS_NR_hER': -1.5390746593475342,
#   'NVS_NR_hFXR_Agonist': -1.2311924695968628,
#   'NVS_NR_hFXR_Antagonist': -1.3194842338562012,
#   'NVS_NR_hGR': -0.9540298581123352,
#   'NVS_NR_hPPARa': -1.807539939880371,
#   'NVS_NR_hPPARg': -2.124666929244995,
#   'NVS_NR_hPR': -0.3989780843257904,
#   'NVS_NR_hPXR': -1.9681077003479004,
#   'NVS_NR_hRAR_Antagonist': -4.477087020874023,
#   'NVS_NR_hRARa_Agonist': -3.935255765914917,
#   'NVS_NR_hTRa_Antagonist': -1.3247150182724,
#   'NVS_NR_mERa': -2.3004038333892822,
#   'NVS_NR_rAR': -1.6498409509658813,
#   'NVS_NR_rMR': -3.825521945953369,
#   'NVS_OR_gSIGMA_NonSelective': 3.147031784057617,
#   'NVS_TR_gDAT': 1.0340993404388428,
#   'NVS_TR_hAdoT': -0.9603701829910278,
#   'NVS_TR_hDAT': 2.226463556289673,
#   'NVS_TR_hNET': 1.8211205005645752,
#   'NVS_TR_hSERT': -0.583428144454956,
#   'NVS_TR_rNET': -1.0649440288543701,
#   'NVS_TR_rSERT': 1.8718922138214111,
#   'NVS_TR_rVMAT2': -0.4529380202293396,
#   'OT_AR_ARELUC_AG_1440': -2.5623819828033447,
#   'OT_AR_ARSRC1_0480': -4.272156715393066,
#   'OT_AR_ARSRC1_0960': -3.6295034885406494,
#   'OT_ER_ERaERa_0480': -5.227518081665039,
#   'OT_ER_ERaERa_1440': -4.4287495613098145,
#   'OT_ER_ERaERb_0480': -3.447195291519165,
#   'OT_ER_ERaERb_1440': -2.4601175785064697,
#   'OT_ER_ERbERb_0480': -4.221306800842285,
#   'OT_ER_ERbERb_1440': -3.7548108100891113,
#   'OT_ERa_EREGFP_0120': -4.115743160247803,
#   'OT_ERa_EREGFP_0480': -4.721022129058838,
#   'OT_FXR_FXRSRC1_0480': -2.801868438720703,
#   'OT_FXR_FXRSRC1_1440': -3.4332923889160156,
#   'OT_NURR1_NURR1RXRa_0480': -2.2985291481018066,
#   'OT_NURR1_NURR1RXRa_1440': -3.618471622467041,
#   'TOX21_ARE_BLA_Agonist_ch1': -6.528774738311768,
#   'TOX21_ARE_BLA_Agonist_ch2': -3.675043821334839,
#   'TOX21_ARE_BLA_agonist_ratio': -2.416264057159424,
#   'TOX21_ARE_BLA_agonist_viability': -6.704897880554199,
#   'TOX21_AR_BLA_Agonist_ch1': -8.562950134277344,
#   'TOX21_AR_BLA_Agonist_ch2': -5.898196220397949,
#   'TOX21_AR_BLA_Agonist_ratio': -6.738592147827148,
#   'TOX21_AR_BLA_Antagonist_ch1': -8.322820663452148,
#   'TOX21_AR_BLA_Antagonist_ch2': -7.055150032043457,
#   'TOX21_AR_BLA_Antagonist_ratio': -3.733212471008301,
#   'TOX21_AR_BLA_Antagonist_viability': -5.516299247741699,
#   'TOX21_AR_LUC_MDAKB2_Agonist': -4.796210289001465,
#   'TOX21_AR_LUC_MDAKB2_Antagonist': -3.1750991344451904,
#   'TOX21_AR_LUC_MDAKB2_Antagonist2': -2.828127384185791,
#   'TOX21_AhR_LUC_Agonist': -2.0714616775512695,
#   'TOX21_Aromatase_Inhibition': -3.1823623180389404,
#   'TOX21_AutoFluor_HEK293_Cell_blue': -7.2837018966674805,
#   'TOX21_AutoFluor_HEK293_Media_blue': -7.223545074462891,
#   'TOX21_AutoFluor_HEPG2_Cell_blue': -7.4721784591674805,
#   'TOX21_AutoFluor_HEPG2_Cell_green': -10.383356094360352,
#   'TOX21_AutoFluor_HEPG2_Media_blue': -8.89607048034668,
#   'TOX21_AutoFluor_HEPG2_Media_green': -10.356659889221191,
#   'TOX21_ELG1_LUC_Agonist': -6.116023063659668,
#   'TOX21_ERa_BLA_Agonist_ch1': -6.265966892242432,
#   'TOX21_ERa_BLA_Agonist_ch2': -4.069130897521973,
#   'TOX21_ERa_BLA_Agonist_ratio': -4.412491321563721,
#   'TOX21_ERa_BLA_Antagonist_ch1': -6.986086845397949,
#   'TOX21_ERa_BLA_Antagonist_ch2': -7.844271183013916,
#   'TOX21_ERa_BLA_Antagonist_ratio': -3.476710081100464,
#   'TOX21_ERa_BLA_Antagonist_viability': -8.117079734802246,
#   'TOX21_ERa_LUC_BG1_Agonist': -2.6881659030914307,
#   'TOX21_ERa_LUC_BG1_Antagonist': -4.717478275299072,
#   'TOX21_ESRE_BLA_ch1': -9.700061798095703,
#   'TOX21_ESRE_BLA_ch2': -6.004795074462891,
#   'TOX21_ESRE_BLA_ratio': -5.720780849456787,
#   'TOX21_ESRE_BLA_viability': -7.736256122589111,
#   'TOX21_FXR_BLA_Antagonist_ch1': -5.386385917663574,
#   'TOX21_FXR_BLA_Antagonist_ch2': -7.769017696380615,
#   'TOX21_FXR_BLA_agonist_ch2': -6.570257663726807,
#   'TOX21_FXR_BLA_agonist_ratio': -6.665864944458008,
#   'TOX21_FXR_BLA_antagonist_ratio': -4.279565334320068,
#   'TOX21_FXR_BLA_antagonist_viability': -7.3169426918029785,
#   'TOX21_GR_BLA_Agonist_ch1': -8.086660385131836,
#   'TOX21_GR_BLA_Agonist_ch2': -6.404839038848877,
#   'TOX21_GR_BLA_Agonist_ratio': -7.350160121917725,
#   'TOX21_GR_BLA_Antagonist_ch2': -7.074495315551758,
#   'TOX21_GR_BLA_Antagonist_ratio': -6.649425983428955,
#   'TOX21_GR_BLA_Antagonist_viability': -8.452159881591797,
#   'TOX21_HSE_BLA_agonist_ch1': -8.504179954528809,
#   'TOX21_HSE_BLA_agonist_ch2': -4.745019435882568,
#   'TOX21_HSE_BLA_agonist_ratio': -4.329022407531738,
#   'TOX21_HSE_BLA_agonist_viability': -8.637316703796387,
#   'TOX21_MMP_ratio_down': -3.1448445320129395,
#   'TOX21_MMP_ratio_up': -4.2192277908325195,
#   'TOX21_MMP_viability': -5.610164165496826,
#   'TOX21_NFkB_BLA_agonist_ch1': -6.920032978057861,
#   'TOX21_NFkB_BLA_agonist_ch2': -4.903700351715088,
#   'TOX21_NFkB_BLA_agonist_ratio': -5.759190082550049,
#   'TOX21_NFkB_BLA_agonist_viability': -4.738246440887451,
#   'TOX21_PPARd_BLA_Agonist_viability': -5.465579032897949,
#   'TOX21_PPARd_BLA_Antagonist_ch1': -6.384658336639404,
#   'TOX21_PPARd_BLA_agonist_ch1': -7.832421779632568,
#   'TOX21_PPARd_BLA_agonist_ch2': -6.3100714683532715,
#   'TOX21_PPARd_BLA_agonist_ratio': -8.424869537353516,
#   'TOX21_PPARd_BLA_antagonist_ratio': -5.145329475402832,
#   'TOX21_PPARd_BLA_antagonist_viability': -10.068431854248047,
#   'TOX21_PPARg_BLA_Agonist_ch1': -11.329801559448242,
#   'TOX21_PPARg_BLA_Agonist_ch2': -7.544328212738037,
#   'TOX21_PPARg_BLA_Agonist_ratio': -6.805953025817871,
#   'TOX21_PPARg_BLA_Antagonist_ch1': -8.172805786132812,
#   'TOX21_PPARg_BLA_antagonist_ratio': -5.0875563621521,
#   'TOX21_PPARg_BLA_antagonist_viability': -8.493916511535645,
#   'TOX21_TR_LUC_GH3_Agonist': -7.848999977111816,
#   'TOX21_TR_LUC_GH3_Antagonist': -1.6999552249908447,
#   'TOX21_VDR_BLA_Agonist_viability': -4.328426361083984,
#   'TOX21_VDR_BLA_Antagonist_ch1': -8.658342361450195,
#   'TOX21_VDR_BLA_agonist_ch2': -7.055017948150635,
#   'TOX21_VDR_BLA_agonist_ratio': -7.4612250328063965,
#   'TOX21_VDR_BLA_antagonist_ratio': -8.02614688873291,
#   'TOX21_VDR_BLA_antagonist_viability': -8.873283386230469,
#   'TOX21_p53_BLA_p1_ch1': -7.544015407562256,
#   'TOX21_p53_BLA_p1_ch2': -5.23731803894043,
#   'TOX21_p53_BLA_p1_ratio': -5.743519306182861,
#   'TOX21_p53_BLA_p1_viability': -7.395278453826904,
#   'TOX21_p53_BLA_p2_ch1': -6.892547130584717,
#   'TOX21_p53_BLA_p2_ch2': -4.701501846313477,
#   'TOX21_p53_BLA_p2_ratio': -4.960855484008789,
#   'TOX21_p53_BLA_p2_viability': -4.847149848937988,
#   'TOX21_p53_BLA_p3_ch1': -4.039714813232422,
#   'TOX21_p53_BLA_p3_ch2': -5.034910202026367,
#   'TOX21_p53_BLA_p3_ratio': -4.735246181488037,
#   'TOX21_p53_BLA_p3_viability': -5.6699934005737305,
#   'TOX21_p53_BLA_p4_ch1': -5.507822513580322,
#   'TOX21_p53_BLA_p4_ch2': -4.642395973205566,
#   'TOX21_p53_BLA_p4_ratio': -4.545684337615967,
#   'TOX21_p53_BLA_p4_viability': -4.884070873260498,
#   'TOX21_p53_BLA_p5_ch1': -7.549738883972168,
#   'TOX21_p53_BLA_p5_ch2': -4.638866424560547,
#   'TOX21_p53_BLA_p5_ratio': -5.769656658172607,
#   'TOX21_p53_BLA_p5_viability': -5.921669960021973,
#   'Tanguay_ZF_120hpf_AXIS_up': -2.2716307640075684,
#   'Tanguay_ZF_120hpf_ActivityScore': -3.2809534072875977,
#   'Tanguay_ZF_120hpf_BRAI_up': -3.5039122104644775,
#   'Tanguay_ZF_120hpf_CFIN_up': -4.395532131195068,
#   'Tanguay_ZF_120hpf_CIRC_up': -5.67218017578125,
#   'Tanguay_ZF_120hpf_EYE_up': -4.085020065307617,
#   'Tanguay_ZF_120hpf_JAW_up': -2.5788488388061523,
#   'Tanguay_ZF_120hpf_MORT_up': -4.403834342956543,
#   'Tanguay_ZF_120hpf_OTIC_up': -4.802125930786133,
#   'Tanguay_ZF_120hpf_PE_up': -2.4156322479248047,
#   'Tanguay_ZF_120hpf_PFIN_up': -3.864189386367798,
#   'Tanguay_ZF_120hpf_PIG_up': -4.3172526359558105,
#   'Tanguay_ZF_120hpf_SNOU_up': -1.7113051414489746,
#   'Tanguay_ZF_120hpf_SOMI_up': -4.566732883453369,
#   'Tanguay_ZF_120hpf_SWIM_up': -4.8493757247924805,
#   'Tanguay_ZF_120hpf_TRUN_up': -4.859918594360352,
#   'Tanguay_ZF_120hpf_TR_up': -3.8597943782806396,
#   'Tanguay_ZF_120hpf_YSE_up': -2.7385342121124268}}
